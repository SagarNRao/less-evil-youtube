# %%
import pandas as pd
import requests
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

# Load the CSV file
df = pd.read_csv("newMerge.csv")

# Create an empty DataFrame to store the results
savedf = pd.DataFrame()

# Collect all video IDs
idArray = df['id'].astype(str).tolist()

# API_KEY = os.getenv("API_KEY")
API_KEY = "AIzaSyBCQnr8GmsG35VdPP4bh6H9cD6cmlQpqFo"

output_file = "IMLnew.csv"

savedf.to_csv(output_file, index=False)

for video_id in idArray:
    url = f'https://youtube.googleapis.com/youtube/v3/videos?part=topicDetails,snippet&id={video_id}&key={API_KEY}'
    response = requests.get(url)

    if response.status_code == 200:
        api_data = response.json()
        if 'items' in api_data and len(api_data['items']) > 0:
            item = api_data['items'][0]

            video_data = {
                'video_id': video_id,
                'title': item['snippet']['title'] if 'snippet' in item else None,
                'description': item['snippet']['description'] if 'snippet' in item else None,
                'channel_name': item['snippet']['channelTitle'] if 'snippet' in item else None,
                'channel_id': item['snippet']['channelId'] if 'snippet' in item else None,
                'tags': ', '.join(item['snippet'].get('tags', [])) if 'snippet' in item else None,
                'topic_details': ', '.join(item['topicDetails'].get('topicCategories', [])) if 'topicDetails' in item else None
            }

            video_df = pd.DataFrame([video_data])

            video_df.to_csv(output_file, mode='a', header=False, index=False)
            print(f"Saved data for video ID {video_id}")
        else:
            empty_data = {
                'video_id': video_id,
                'title': None,
                'description': None,
                'channel_name': None,
                'channel_id': None,
                'tags': None,
                'topic_details': None
            }
            empty_df = pd.DataFrame([empty_data])
            empty_df.to_csv(output_file, mode='a', header=False, index=False)
            print(f"No data found for video ID {video_id}")
    else:
        empty_data = {
            'video_id': video_id,
            'title': None,
            'description': None,
            'channel_name': None,
            'channel_id': None,
            'tags': None,
            'topic_details': None
        }
        empty_df = pd.DataFrame([empty_data])
        empty_df.to_csv(output_file, mode='a', header=False, index=False)
        print(f"Failed to fetch data for video ID {video_id}: {response.json()}")

print("Data fetching complete. Results saved to response_data.csv")
# Out:
# Saved data for video ID IHZwWFHWa-w
# Saved data for video ID qg4PchTECck
# Saved data for video ID sDv4f4s2SB8
# Saved data for video ID i62czvwDlsw
# Saved data for video ID QoK1nNAURw4
# Saved data for video ID Anc2_mnb3V8
# Saved data for video ID UmathvAKj80
# Saved data for video ID AeRwohPuUHQ
# Saved data for video ID QhSI9wo9f7I
# Saved data for video ID iudXf5n_3ro
# Saved data for video ID vMh0zPT0tLI
# Saved data for video ID FpDsDn-fBKA
# Saved data for video ID Souzjv6WfrY
# Saved data for video ID vsWrXfO3wWw
# Saved data for video ID gzrQvzYEvYc
# Saved data for video ID fXQXE96r4AY
# Saved data for video ID pXGBHV3y8rs
# Saved data for video ID BQW7sYAO_AA
# Saved data for video ID _QzwKfQ3b8Y
# Saved data for video ID giZD8yzXEZ4
# Saved data for video ID yi8vowoMbxk
# Saved data for video ID XdWFHKQw6HI
# Saved data for video ID GdGzclW78aI
# Saved data for video ID yRsRu4sGdQw
# Saved data for video ID UfvGq9q87q4
# Saved data for video ID tQYwjzrixDU
# Saved data for video ID D3AGw8QzjuE
# Saved data for video ID YS_EztqZCD8
# Saved data for video ID hMLUgM6kTp8
# Saved data for video ID jc2IthslyzM
# Saved data for video ID IU5fuoYBTAM
# Saved data for video ID 7z6yXpYk7sw
# Saved data for video ID 1j4bERmqmOU
# Saved data for video ID jwStsp8JUPU
# Saved data for video ID uJryes5Vk1o
# Saved data for video ID ktGm0WCoQOg
# Saved data for video ID k3AiUhwHQ28
# Saved data for video ID 4b4MUYve_U8
# Saved data for video ID ORyfPJypKuU
# Saved data for video ID EfsjEOb596Q
# Saved data for video ID _4X07liONGI
# Saved data for video ID 5hB4_8o34GU
# Saved data for video ID 4M-vj_KwWwI
# Saved data for video ID erfeZg27B7A
# Saved data for video ID dK4veEQnt2I
# Saved data for video ID umAeJ7LMCfU
# Saved data for video ID IDfE5jYWExg
# Saved data for video ID 1xMs6A3DLYw
# Saved data for video ID gj4g7CzDzJE
# Saved data for video ID 8zb9nsi8KzA
# Saved data for video ID ewN0vFYFJ7A
# Saved data for video ID wrEcHhoJxjM
# Saved data for video ID FjfrGjEc1-E
# Saved data for video ID rOzv1q1okJU
# Saved data for video ID KshIEHQn5ZM
# Saved data for video ID Ilg3gGewQ5U
# Saved data for video ID gsfbWn4Gy5Q
# Saved data for video ID cxPAvoIbsIk
# Saved data for video ID 0kFydRfswU8
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID k8fTYJPd3_I
# Saved data for video ID Lw3Yf8xxwKI
# Saved data for video ID 5h8yx6zalXM
# Saved data for video ID odlgtjXduVg
# Saved data for video ID dIYDPtHWBNA
# Saved data for video ID 4PHI11lX11I
# Saved data for video ID 31w-xQX0Z_8
# Saved data for video ID WyAZ97igZxA
# Saved data for video ID BZ10SGWtU-s
# Saved data for video ID kmb5FuFCZKE
# Saved data for video ID Aym1Gx2wVK4
# Saved data for video ID AvwTSd1kVRk
# Saved data for video ID _xxngcHNRlk
# Saved data for video ID MUoEv1Hv0KM
# Saved data for video ID SmZmBKc7Lrs
# Saved data for video ID l7c8_D6Z97c
# Saved data for video ID 87wejP5mLBA
# Saved data for video ID Q0TtSM9aRew
# Saved data for video ID ZypmhnzH-AY
# Saved data for video ID YJEfZ5EVyPA
# Saved data for video ID GK5ATUhdH74
# Saved data for video ID t6MVuMavbBY
# Saved data for video ID gJFJgiFE79Y
# Saved data for video ID wjhT2YFNmlw
# Saved data for video ID D4zMKh3krPc
# Saved data for video ID L-Lsfu4ab74
# Saved data for video ID 4qJaSmvhxi8
# Saved data for video ID BBIJkaCcmzY
# Saved data for video ID gSaatcLqbsQ
# Saved data for video ID nMnznn68WwI
# Saved data for video ID VkJnA3Y77cg
# Saved data for video ID zniSoDvx4AI
# Saved data for video ID V7KBAa_gh4c
# Saved data for video ID sTQDy8FyVY0
# Saved data for video ID RXgF14WblVo
# Saved data for video ID KjBI1WosQUc
# Saved data for video ID QmQ0Mi2XwRI
# Saved data for video ID KtoXoTu7x8A
# Saved data for video ID IDiO2ffYpHg
# Saved data for video ID VBOxg62CwCg
# Saved data for video ID lAZEEM2WGr0
# Saved data for video ID 5BCUPgmeZdU
# Saved data for video ID D_SAut2Y3PY
# Saved data for video ID xBupkA4Juzs
# Saved data for video ID LYVQXwT-odY
# Saved data for video ID ibKP0nIT7YU
# Saved data for video ID 9H-s5cQ1iBk
# Saved data for video ID gwI1FRhVsAE
# Saved data for video ID cBn8JGkcWlc
# Saved data for video ID O129bEPkBf8
# Saved data for video ID 0SX_GAgMNkA
# Saved data for video ID WNBu7CWaEDE
# Saved data for video ID o6FfdP2uYh4
# Saved data for video ID T5p6GZiH-Yw
# Saved data for video ID RUMqUCqjtLw
# Saved data for video ID 5zqo-JzI4J8
# Saved data for video ID sV9aiEsXanE
# Saved data for video ID cJVkqh7-EZs
# Saved data for video ID GyrJq-pl63w
# Saved data for video ID OfT28rn9bHs
# Saved data for video ID SV4lmrD1H7s
# Saved data for video ID 5um66zYfWNQ
# Saved data for video ID 9x6Ku1A92X4
# Saved data for video ID fpYC7KK5t7A
# Saved data for video ID S-xOow1e2hg
# Saved data for video ID CbAouorkYHE
# Saved data for video ID pPusWWC-HQs
# Saved data for video ID KoVz3r4AJh0
# Saved data for video ID Nb20syxsCac
# Saved data for video ID TN7j7E39I_8
# Saved data for video ID jxkbuwpJdCI
# Saved data for video ID HArazhj-Ju0
# Saved data for video ID qyGPheuLMYc
# Saved data for video ID L2YiNu22saU
# Saved data for video ID -5dPMOtghT4
# Saved data for video ID bQjDdk5k1E0
# Saved data for video ID ktXWumtwTrw
# Saved data for video ID IemYakcygzM
# Saved data for video ID Jyo53pAyVAM
# Saved data for video ID FO4J3yZjDts
# Saved data for video ID 7pWJnwSq9Fs
# Saved data for video ID 1Ec7Eoa5W7g
# Saved data for video ID BqbYys0Xkug
# Saved data for video ID ncMDqkXFBy0
# Saved data for video ID eGW0YgWOB5k
# Saved data for video ID 676mvkFCbcc
# Saved data for video ID E3nwEa6JELw
# Saved data for video ID HcAGThqN7UE
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID JO21WRsouXA
# Saved data for video ID _scscQ4HVTY
# Saved data for video ID nIvu1s1xQUg
# Saved data for video ID 7fkZyreLEIY
# Saved data for video ID tgm7Gw8mPyg
# Saved data for video ID AKdieG_5H68
# Saved data for video ID Iu5eGkP1u38
# Saved data for video ID rcl_YRyoLIY
# Saved data for video ID mLPTeBMu1ys
# Saved data for video ID 9Hjhgx2xfNo
# Saved data for video ID e0k9ERORMC8
# Saved data for video ID ELn277w39Pw
# Saved data for video ID Ob-AxSwNTFA
# Saved data for video ID O3yBZlTYQI0
# Saved data for video ID qvZ_B1v2z8w
# Saved data for video ID IcQDroiVuwQ
# Saved data for video ID E9xOrE4WZuM
# Saved data for video ID nJfUZBrl8Ms
# Saved data for video ID _ZjAtHtYirk
# Saved data for video ID A5h7xrHh0s8
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID RO0cDCnPeyE
# Saved data for video ID fUIYSKzirrk
# Saved data for video ID X5NCFy1L0dk
# Saved data for video ID Oe3wdOMIV0A
# Saved data for video ID SLE6qMYA8ZI
# Saved data for video ID 4qDt4QUl4zE
# Saved data for video ID ywTp1qJcUBU
# Saved data for video ID ap6LOok_Vtk
# Saved data for video ID s_SQ2TXKZDI
# Saved data for video ID Ab_UObr16pM
# Saved data for video ID J-uJl3bKxuY
# Saved data for video ID xngpBORNVjc
# Saved data for video ID tnSJoPnWZ98
# Saved data for video ID 87HYEKtoLvg
# Saved data for video ID kPwOkH3-KvQ
# Saved data for video ID mLqJxMoYNBs
# Saved data for video ID aQICO-zCu8U
# Saved data for video ID 6DIObA3IWyg
# Saved data for video ID xoP7M92b5TY
# Saved data for video ID fjjK01Z3tr4
# Saved data for video ID EKbFIWANwHw
# Saved data for video ID Atq7ryMEw08
# Saved data for video ID rNU2dSL4Yrw
# Saved data for video ID Z3c7g7jQwY4
# Saved data for video ID 7b-DDZRJJ_8
# Saved data for video ID WJJp4U8FxFo
# Saved data for video ID Ce5dL-QbqIs
# Saved data for video ID YQz7fTGsQnA
# Saved data for video ID f_ka2yhq9q4
# Saved data for video ID V60ylfHqTe8
# Saved data for video ID T-USd3Sv59I
# Saved data for video ID 7zxSsQ7DMU0
# Saved data for video ID s4pUMygI_GY
# Saved data for video ID 9M2FYc_hYL8
# Saved data for video ID U6Z-UjkJZjA
# Saved data for video ID A4yRv9dgHGs
# Saved data for video ID FeEUeX0NlDg
# Saved data for video ID leQKdgyRnuU
# Saved data for video ID mBZJfl5EUYs
# Saved data for video ID At-dn0AQJ3Q
# Saved data for video ID KZmPd41CuEM
# Saved data for video ID FKCV76N9Ys0
# Saved data for video ID NPX9H6zcuYI
# Saved data for video ID JJhq3ZeEvY4
# Saved data for video ID JXKphCqzLv0
# Saved data for video ID SZWTc31q0eg
# Saved data for video ID _pCtRAGLfjQ
# Saved data for video ID UvXir4IpBJM
# Saved data for video ID aNngwhg1dyU
# Saved data for video ID 7QzNifIDXDw
# Saved data for video ID _x2-XzOovf0
# Saved data for video ID HPTWr5I4Zzs
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID rdJ0H13Hr58
# Saved data for video ID c4mJ6aKjqS0
# Saved data for video ID Ezu2DMUYThY
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID pW_gg0CFPFE
# Saved data for video ID nvHIOWtnFx4
# Saved data for video ID rw1gtS-Meiw
# Saved data for video ID KMF8WIFTRVo
# Saved data for video ID mZAe73NpOoE
# Saved data for video ID UCscplSiaWg
# Saved data for video ID 6pqCsSl4ZV8
# Saved data for video ID FiwhfsS6RWA
# Saved data for video ID IaTAwjMIUjI
# Saved data for video ID qED_MFk6NrA
# Saved data for video ID nrhAwASxAJA
# Saved data for video ID brjU-22JhII
# Saved data for video ID WACw0UPl3BA
# Saved data for video ID J_m8wMkP1rw
# Saved data for video ID ZRAFA5oxhAI
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID qqwyp-TfiWI
# Saved data for video ID j9t5TWr5Vt4
# Saved data for video ID h_XjWl73Jso
# Saved data for video ID Fv81idC1Mgo
# Saved data for video ID jl5LjHyrgBg
# Saved data for video ID 9kDu5Cet290
# Saved data for video ID BQPOjsuOjYo
# Saved data for video ID dcQQfDBq4Ss
# Saved data for video ID WoR3S7tFsQk
# Saved data for video ID WOfI6AHFcV0
# Saved data for video ID CHmQ2F2vyJI
# Saved data for video ID BdiipHHmCqI
# Saved data for video ID xsQi5cS_lDw
# Saved data for video ID LzXakYdtAOo
# Saved data for video ID JmQzj0Be_Fg
# Saved data for video ID XPaDOAD4dLY
# Saved data for video ID 32SWOQWwzY0
# Saved data for video ID 5XzsxEDcMLI
# Saved data for video ID Hj8LkVMUZTQ
# Saved data for video ID V8InSDYHG4s
# Saved data for video ID MqKQtUfKQ7w
# Saved data for video ID P_rSOHZETsM
# Saved data for video ID aFT0vXv3Ag8
# Saved data for video ID ypZdwetUhCs
# Saved data for video ID wqRWRrgvYqA
# Saved data for video ID a4xaK0dsZ_c
# Saved data for video ID uM0BOdLEULg
# Saved data for video ID BSoej8cNGag
# Saved data for video ID H8RsdeAiOBg
# Saved data for video ID ENYJeL6ttQA
# Saved data for video ID VwB5GeATW9Q
# Saved data for video ID VOIbJvnwxDQ
# Saved data for video ID AJPg0khuGZQ
# Saved data for video ID KW34-aOnaMM
# Saved data for video ID 0hzFtjHTsYs
# Saved data for video ID xrPZbHrxrWo
# Saved data for video ID ABrrSwMYWSg
# Saved data for video ID ZydKMk22rbo
# Saved data for video ID OouPxtRaMlY
# Saved data for video ID leU9zH9FMl8
# Saved data for video ID 8s-CKu4uGHk
# Saved data for video ID 4DK-B5zPeEc
# Saved data for video ID Ahh5-hEM82A
# Saved data for video ID UKHCH8ZdH1Y
# Saved data for video ID BBlDWNTimoA
# Saved data for video ID vwInkakadcg
# Saved data for video ID 1vE3ft75j9s
# Saved data for video ID jeJaeByfFMg
# Saved data for video ID Ui3Fh-NY74w
# Saved data for video ID VEpsyYx0Byo
# Saved data for video ID jXShvxPcRl4
# Saved data for video ID V39sJEANQDo
# Saved data for video ID Qib-Rz0gy1I
# Saved data for video ID 0Vx0MZCUfKM
# Saved data for video ID fxX9f4FplQg
# Saved data for video ID dboM7Ra3z7M
# Saved data for video ID 4061WI4BEfY
# Saved data for video ID v0vwOU_rBbY
# Saved data for video ID ek2_aYM0ZiU
# Saved data for video ID yCZHlCvvTGg
# Saved data for video ID 1HcQXu3UXyQ
# Saved data for video ID D93YSyprG1s
# Saved data for video ID qOeU9GCnU3w
# Saved data for video ID DiGeSxo5nVE
# Saved data for video ID zB206XhmybQ
# Saved data for video ID z5xa7zEJSVU
# Saved data for video ID ZBTOeTBTLUk
# Saved data for video ID LNCQCOWCaDU
# Saved data for video ID d21GQqAg_Oc
# Saved data for video ID tHxTyPEgQvg
# Saved data for video ID ty_lrxZk4cA
# Saved data for video ID 3XEstBLJwdQ
# Saved data for video ID znVcfdVILs0
# Saved data for video ID Qat4W--YQMw
# Saved data for video ID Tayl4-wLdJQ
# Saved data for video ID UBrI_8OjNbk
# Saved data for video ID efgzYVTBwho
# Saved data for video ID aeM-fmcdkXU
# Saved data for video ID gP08yEvEPRc
# Saved data for video ID N6rarwBexEk
# Saved data for video ID HxtmOCvRUfw
# Saved data for video ID Hxv_y_bI3zA
# Saved data for video ID ucvbkSUCkNI
# Saved data for video ID G5zpk4Xyh-Q
# Saved data for video ID Lxus_GwYUSE
# Saved data for video ID wS4E4wWY-rw
# Saved data for video ID WjVKhXWOBfc
# Saved data for video ID ErpIw2ohNMs
# Saved data for video ID JTwSY0bT7aA
# Saved data for video ID V4AcLJ2cgmU
# Saved data for video ID HdlDYng8g9s
# Saved data for video ID G-fXV-o9QV8
# Saved data for video ID DTcfH5W6o08
# Saved data for video ID 82fPl5l0vXY
# Saved data for video ID 7sPGKWlHJbk
# Saved data for video ID vnXx7t2pnvQ
# Saved data for video ID jUxhUgkKAjE
# Saved data for video ID oMZA8v4JECY
# Saved data for video ID 355u2bDqB7c
# Saved data for video ID wKkcBPp3F1Y
# Saved data for video ID lfiw2Rh2v8k
# Saved data for video ID 5Xh9FusE8iE
# Saved data for video ID cyIINCqyi5g
# Saved data for video ID iC5ZEr2GYo8
# Saved data for video ID 8hZ_cBwNOss
# Saved data for video ID 36UzNrthTUs
# Saved data for video ID swASK24LjBU
# Saved data for video ID 81uQFOmQoi4
# Saved data for video ID nDncZnNRp4E
# Saved data for video ID CU5R9c3Wc60
# Saved data for video ID LrCylIe0RJM
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID Vbl6eeEZ84E
# Saved data for video ID _xFxRLGLhY4
# Saved data for video ID 0DLAvq0VTJg
# Saved data for video ID R5eJgjn9bnw
# Saved data for video ID gml85V645NI
# Saved data for video ID QCtCuntgGJs
# Saved data for video ID o0nNKZNjokM
# Saved data for video ID iH19cZD36Ys
# Saved data for video ID m3kDJCWuoTg
# Saved data for video ID WXeVrO6cQMM
# Saved data for video ID M-NTkxfd7-8
# Saved data for video ID KFdPZFysZ8U
# Saved data for video ID PK37PqkIOg4
# Saved data for video ID leXkKQU3QsM
# Saved data for video ID qvjTqEMq8_8
# Saved data for video ID OkAoiA6A2Ac
# Saved data for video ID gHTJgBBmygQ
# Saved data for video ID tSM-WLNvzD4
# Saved data for video ID lGTHIzCInqQ
# Saved data for video ID HP9ggPV4MbY
# Saved data for video ID eEVDIOiYuMk
# Saved data for video ID FscOZT0_ObA
# Saved data for video ID 2HtpZkcGc70
# Saved data for video ID KFost_u85YI
# Saved data for video ID MJKXlANTV3I
# Saved data for video ID UIVDdlLCJc8
# Saved data for video ID Q7kbMDce1iw
# Saved data for video ID OK93OFX1yyc
# Saved data for video ID 2IuwIdHZiw4
# Saved data for video ID IuHA9uegWIE
# Saved data for video ID yRZ4EFVvayk
# Saved data for video ID ip0Ywb6KAkE
# Saved data for video ID a8ky6jNzntg
# Saved data for video ID kMd_dQau5fo
# Saved data for video ID qgzubmKglv0
# Saved data for video ID 1CcaJxLV1mE
# Saved data for video ID xNsoDn6Io1M
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID cq5IK8pr8cQ
# Saved data for video ID _JG7Aa8thgE
# Saved data for video ID Z4vEzrjae7w
# Saved data for video ID MJbzBIexPQY
# Saved data for video ID 2_mv3e71tNs
# Saved data for video ID ttE0F7fghfk
# Saved data for video ID 6lUrhldqDXY
# Saved data for video ID _mWh6ApsquI
# Saved data for video ID WsT4T6Zo1cE
# Saved data for video ID CfIQC9DKcdA
# Saved data for video ID loEBd1DwgV0
# Saved data for video ID nhWhfPDaChw
# Saved data for video ID PBzUJ9SmhHg
# Saved data for video ID ETczAYgfRh8
# Saved data for video ID pYM6L0H89PY
# Saved data for video ID v-JRikgtLjE
# Saved data for video ID soilQNNvhLw
# Saved data for video ID RGPDtlhgh8I
# Saved data for video ID pqVJ-bD__HY
# Saved data for video ID xGZVxxvgzI4
# Saved data for video ID 7p6kz4-Pr7M
# Saved data for video ID msEf6TZhWvg
# Saved data for video ID n_Ink-Z7rPU
# Saved data for video ID WN9kqIDr0jo
# Saved data for video ID 1OVdPO4RS0w
# Saved data for video ID 50MT_21o_iI
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID rQoFQz3ml10
# Saved data for video ID sAdnlw0-U7g
# Saved data for video ID vTS1r3ypSWU
# Saved data for video ID ioFdUAFUM6w
# Saved data for video ID ZxlpdBe3VSU
# Saved data for video ID u4K50jU6h5M
# Saved data for video ID xLQQFXiSf7U
# Saved data for video ID F13pKaJ1u7w
# Saved data for video ID 2pshSPNWEVs
# Saved data for video ID nL6ur5NzYr8
# Saved data for video ID AurXqJ-Sr6o
# Saved data for video ID nIKVlosDvrc
# Saved data for video ID Qo3FORVp3EI
# Saved data for video ID HyaMxd7Idfo
# Saved data for video ID fNZavBphDsg
# Saved data for video ID pVM2ulwIKck
# Saved data for video ID Cdl0ee2TPdo
# Saved data for video ID Ylt7Htnl1zY
# Saved data for video ID thwj5COk5RY
# Saved data for video ID xqeowPhNr48
# Saved data for video ID Oq4sRAId7RQ
# Saved data for video ID zRdf63tRuiQ
# Saved data for video ID tzLabVxMOZU
# Saved data for video ID OYBlFDq7-LY
# Saved data for video ID aagpYgEthA0
# Saved data for video ID eBcWmyeG1xg
# Saved data for video ID kUbP5SpSuQ0
# Saved data for video ID v6-SZZNeQYs
# Saved data for video ID CdTqHbFMePM
# Saved data for video ID Qu8G3rYKQa0
# Saved data for video ID UxUbuHglpb8
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID aiqxOvBiRWU
# Saved data for video ID E0OoOgHXqRI
# Saved data for video ID 1WqBQDe3LpE
# Saved data for video ID dUtn98bFE1w
# Saved data for video ID 4RN46Gftt4A
# Saved data for video ID 3hF_tbwuRf0
# Saved data for video ID IaVtPRo_clQ
# Saved data for video ID wTjjFiiL6uM
# Saved data for video ID _GBjqskD8Qk
# Saved data for video ID TIDYKOfzBYk
# Saved data for video ID 9iR01rW01Tw
# Saved data for video ID Im2J5BjoD-8
# Saved data for video ID EJePX80Bqgc
# Saved data for video ID BBLtozP0oOM
# Saved data for video ID 3RbwrDb5S_c
# Saved data for video ID YsYXj6-lgAw
# Saved data for video ID ZVIATZjKYzs
# Saved data for video ID E2b3SKMw934
# Saved data for video ID 8I99EH0PeSM
# Saved data for video ID lbmoX6Iwu4o
# Saved data for video ID L-PRQTv5apY
# Saved data for video ID GQ7atd-iSC4
# Saved data for video ID 1WkmlpDRgoA
# Saved data for video ID DZPrsMRw9GY
# Saved data for video ID ZZTG72rnVgc
# Saved data for video ID fkyQc2Jypa0
# Saved data for video ID HkQEOJBdeJ4
# Saved data for video ID iAJQeRfOjDI
# Saved data for video ID YNdiBfoyDB0
# Saved data for video ID fFP2aFPnctU
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID WQj4iry11y4
# Saved data for video ID 2y52WqOV7TI
# Saved data for video ID Z01GySY4_jE
# Saved data for video ID sndqJkBG0WY
# Saved data for video ID r0g-SNXZBFc
# Saved data for video ID eoiLiaxH9F8
# Saved data for video ID GhLpXsa73HU
# Saved data for video ID qz6kko0mmbA
# Saved data for video ID 2BlDpex1Wrk
# Saved data for video ID pEubZU2q8Us
# Saved data for video ID y9DYyqD3kMs
# Saved data for video ID kCfhfJxXOOA
# Saved data for video ID caQ0VaUEl0g
# Saved data for video ID 7s_6-YjtKL0
# Saved data for video ID nlLfbUdkZiY
# Saved data for video ID nN-ddXnW-_k
# Saved data for video ID y_YVaC_kw7c
# Saved data for video ID 8c-Qo2u12XM
# Saved data for video ID d-szlxDjfR8
# Saved data for video ID j0MOGKBqx7E
# Saved data for video ID 82QgJLcpkDQ
# Saved data for video ID I8J3_p_zlsA
# Saved data for video ID kbXUnLQqSsQ
# Saved data for video ID AIQd1SxSjsw
# Saved data for video ID u3N5ZInSQtA
# Saved data for video ID eZ98q7iOUAA
# Saved data for video ID 8a2WfFkB8VQ
# Saved data for video ID nJckuB9oJV4
# Saved data for video ID xRhPwQdNMss
# Saved data for video ID L0RU8VvxuVU
# Saved data for video ID DsdtxLGjJ24
# Saved data for video ID qt7oTZUwrzQ
# Saved data for video ID E7LC8tVY5oo
# Saved data for video ID 7h59kWnEsQw
# Saved data for video ID xP9l9MptIZo
# Saved data for video ID X7qWKw-9fuc
# Saved data for video ID ND2D2Cy5IVk
# Saved data for video ID 467eE9LeSe8
# Saved data for video ID yaBxEUxRXZI
# Saved data for video ID m5tQJXL8UfY
# Saved data for video ID 9HomdnM12o4
# Saved data for video ID lEyzSXPAO-Q
# Saved data for video ID q6ykKb_SSh4
# Saved data for video ID FJtHwV6rro4
# Saved data for video ID ljTlImCBxMY
# Saved data for video ID LzZyVLJZgpU
# Saved data for video ID YCnUL_SgjS8
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID BMPVBVo4ckU
# Saved data for video ID qLVd1aRxOGc
# Saved data for video ID PnJu94VP_h0
# Saved data for video ID Gh-W9z5VtZY
# Saved data for video ID Kbra--CoGak
# Saved data for video ID NW3G3U6iNkE
# Saved data for video ID 53lahYcewjM
# Saved data for video ID GSrhdgpfWSA
# Saved data for video ID uW5lkH8qLVA
# Saved data for video ID z-K-hBQOOQ4
# Saved data for video ID KG13s9odx2I
# Saved data for video ID Br5NZ7J2VDg
# Saved data for video ID GB80-C_xyvc
# Saved data for video ID YtMjajBS1z8
# Saved data for video ID ityuuDlAOM0
# Saved data for video ID _wVKk8J6p8c
# Saved data for video ID bb1l7hu23jQ
# Saved data for video ID YSMc69e-smY
# Saved data for video ID FDyCfgnRJbc
# Saved data for video ID L7EEdA8bUQM
# Saved data for video ID xFF1fxGsNOM
# Saved data for video ID 9f2SWt1QTtQ
# Saved data for video ID rIKsYAlVoSo
# Saved data for video ID LZQE90whvfY
# Saved data for video ID gqnzka6uc5w
# Saved data for video ID 5wjRcXWhQyY
# Saved data for video ID QIMuscrs2z4
# Saved data for video ID kTSsGw1x7EU
# Saved data for video ID pEDMdI3DxGw
# Saved data for video ID hqhXNqQw7ho
# Saved data for video ID _lWQn1-Q1j4
# Saved data for video ID AX5u7lsZfQU
# Saved data for video ID y-9G41zELIY
# Saved data for video ID wy0cFK7BEFY
# Saved data for video ID BHECt19KpMg
# Saved data for video ID fyih6NJaP1w
# Saved data for video ID punYWEAG4kU
# Saved data for video ID QqXr70fT670
# Saved data for video ID qUy_9-pipTE
# Saved data for video ID YBJd8BQWK8Q
# Saved data for video ID gMxAnWTueCw
# Saved data for video ID 32tNAhQ8x7M
# Saved data for video ID rfF0BkkTTW4
# Saved data for video ID mhvqfcguLCw
# Saved data for video ID aP1H6ckszjs
# Saved data for video ID Bzsxq1JJbbo
# Saved data for video ID Z9N-IsGry8U
# Saved data for video ID mA7Tc5agc6w
# Saved data for video ID avQY3-v9fXE
# Saved data for video ID f2bkNtYt_SE
# Saved data for video ID pwJG4lJIys8
# Saved data for video ID 6BqFZ_aub_s
# Saved data for video ID lKusotIjzwk
# Saved data for video ID gfnE9SE2pFs
# Saved data for video ID ShAaFXCuMY0
# Saved data for video ID q2BjenDIsA8
# Saved data for video ID WwJAFRZZS_c
# Saved data for video ID ZeWXOFXXldg
# Saved data for video ID P6NwZVl8ttc
# Saved data for video ID TF9bFPYCHoM
# Saved data for video ID Q3Cs0sn9Blw
# Saved data for video ID oEeKIAJ1FgA
# Saved data for video ID t-INgABWULw
# Saved data for video ID qgV9W2LGegU
# Saved data for video ID nRHUNoMkrfA
# Saved data for video ID YVDUDdH83vs
# Saved data for video ID OSJOBH2-a9Y
# Saved data for video ID TvB_3jVIHhg
# Saved data for video ID jQWBtP3v1K8
# Saved data for video ID K9SFOn52oB0
# Saved data for video ID i2t8HwIHejo
# Saved data for video ID n2l33cyg1zA
# Saved data for video ID SctFnD_puQI
# Saved data for video ID IpICZEpyy-c
# Saved data for video ID Th2Wf8YjtaU
# Saved data for video ID FnWOFssskJc
# Saved data for video ID 4RN46Gftt4A
# Saved data for video ID ULXQdUMKseM
# Saved data for video ID 8jMA98fLwmU
# Saved data for video ID OPaAhInecJM
# Saved data for video ID wi6WSpfoM7Y
# Saved data for video ID SbB81i98QpQ
# Saved data for video ID bEaeIA-Iti8
# Saved data for video ID ECNU4WIuhSE
# Saved data for video ID csae_xWc1kw
# Saved data for video ID UFSTQc9mk-k
# Saved data for video ID 2QX6jjMt1Eg
# Saved data for video ID 9JjTURTW41w
# Saved data for video ID XgKcLS4kHAY
# Saved data for video ID MTGBrfQ20xk
# Saved data for video ID x9cty3Hxufc
# Saved data for video ID pKxrm26ACa4
# Saved data for video ID 4Im0CT43QxY
# Saved data for video ID N-CoIoPSdYs
# Saved data for video ID WZvG6hwxUEw
# Saved data for video ID HDIFYB8Qsfo
# Saved data for video ID Y_KDgaZbnUk
# Saved data for video ID DHxsNrL7Zfw
# Saved data for video ID dA_x2xHTYQE
# Saved data for video ID xNLXQ9hjGzM
# Saved data for video ID awXhxYkPGYg
# Saved data for video ID XpjiHU1yyrA
# Saved data for video ID Nz3wsWFNRQg
# Saved data for video ID 203zKEecHgg
# Saved data for video ID g7YiyOPVdXE
# Saved data for video ID VVI4zu6G9YI
# Saved data for video ID NJTUbCoFwsM
# Saved data for video ID X2sx1lAsulQ
# Saved data for video ID IzjmuGJgwKQ
# Saved data for video ID 614S6vA7zik
# Saved data for video ID aMPipqJ8dro
# Saved data for video ID bfFhuj1aBpU
# Saved data for video ID iX8CBCYghkI
# Saved data for video ID eXZLxRPOzzQ
# Saved data for video ID lFughnnbBi4
# Saved data for video ID YBJd8BQWK8Q
# Saved data for video ID jzig36e51V4
# Saved data for video ID 4qcgqOCDv2c
# Saved data for video ID 7XSgmiy4ly0
# Saved data for video ID MeEkAYsNrgo
# Saved data for video ID AvWfL1Us3Kg
# Saved data for video ID QSUFvXnyyUg
# Saved data for video ID mIbIycwPwUA
# Saved data for video ID q08ZDZhUZ-g
# Saved data for video ID ZrIcll1cMJs
# Saved data for video ID qqo3fO0WXZ0
# Saved data for video ID 6Nf1x7qThR8
# Saved data for video ID V1A3LkQ_ks4
# Saved data for video ID Y3s-wBBLj_o
# Saved data for video ID WOFVY_wQ9wU
# Saved data for video ID BPrfA3XiPvY
# Saved data for video ID ZXWv3aA8JsI
# Saved data for video ID LVI6H0qHlnY
# Saved data for video ID JGG5lkHAF9s
# Saved data for video ID c4mS7KaOIGY
# Saved data for video ID 4lR7gP7dTSQ
# Saved data for video ID QUvL3gEUfqY
# Saved data for video ID ayCnhYD2F24
# Saved data for video ID rO3g9DZXm8s
# Saved data for video ID CjRMBQPY1RQ
# Saved data for video ID PbX4nHEOe0o
# Saved data for video ID pLpKnSXPc2M
# Saved data for video ID CfPJb5iAsKg
# Saved data for video ID 4b5d3muPQmA
# Saved data for video ID KzJORp8bgqs
# Saved data for video ID 5FpsGnkbEpM
# Saved data for video ID EItlUEPCIzM
# Saved data for video ID CLKW6uWJtTc
# Saved data for video ID 5shTLzwAdEc
# Saved data for video ID R2e3Ls9H_fc
# Saved data for video ID 5aBjP9Tn2lc
# Saved data for video ID nW7btpcyNu0
# Saved data for video ID 190xjQHVdrE
# Saved data for video ID GZj6ikx8PAc
# Saved data for video ID AWKCCK5YHsE
# Saved data for video ID 5I3Ei69I40s
# Saved data for video ID cByoAh5hkaw
# Saved data for video ID 3tLdD-4-wnI
# Saved data for video ID z2yncM2HE6M
# Saved data for video ID afPJeQuVeuY
# Saved data for video ID QXOkPvFM6NU
# Saved data for video ID yR7k19YBqiw
# Saved data for video ID lX-3nGHDhQg
# Saved data for video ID Aa4MACKaDC0
# Saved data for video ID _aWzGGNrcic
# Saved data for video ID iNlZ3IU5Ffw
# Saved data for video ID 22mpExWh1LY
# Saved data for video ID _FXSdSvzt4s
# Saved data for video ID kfjGoske6XU
# Saved data for video ID SllfgMlszC4
# Saved data for video ID LbBRT5nFX3Q
# Saved data for video ID LmpkKwsyQj4
# Saved data for video ID lRnbIyjCAeU
# Saved data for video ID wW1tgWtkj4I
# Saved data for video ID z8uvCejr5Qk
# Saved data for video ID AYcf-YEF09Y
# Saved data for video ID 461Opp1TShk
# Saved data for video ID esmzYhuFnds
# Saved data for video ID Cyxf5Qlo9_A
# Saved data for video ID T8MkpOAow9o
# Saved data for video ID A8auassRatE
# Saved data for video ID Xvwt7y2jf5E
# Saved data for video ID 5w5iUbTlpMQ
# Saved data for video ID 6UF5Ysk_2gk
# Saved data for video ID OClrEI_5Ri4
# Saved data for video ID 2PHC4djQlsA
# Saved data for video ID NBfCgbkLwfg
# Saved data for video ID NH49JTvffo4
# Saved data for video ID efKGmOH4Y_A
# Saved data for video ID YykHl15hxdM
# Saved data for video ID ZbwMvU8WrCU
# Saved data for video ID NKQpVU1LTm8
# Saved data for video ID UPvv9SprgVo
# Saved data for video ID Sj_8RsqyTCY
# Saved data for video ID D8I91POKxJA
# Saved data for video ID 9JEViEvNzkg
# Saved data for video ID RDZUdRSDOok
# Saved data for video ID 6YHELmZLQKM
# Saved data for video ID 3APHaJcB6vM
# Saved data for video ID Lr5fIOSyk40
# Saved data for video ID r0XscelDiAY
# Saved data for video ID G8WnPM1nQZ8
# Saved data for video ID K1quNyRP86Q
# Saved data for video ID wpm3bxZ5X5M
# Saved data for video ID 2PHC4djQlsA
# Saved data for video ID bnDMXYXnwAM
# Saved data for video ID H3PKgTeVKY4
# Saved data for video ID 1R7-1hhhR1M
# Saved data for video ID 2kfY0R34Dy0
# Saved data for video ID JxX5OvCn13Y
# Saved data for video ID ChBxx4aR-bY
# Saved data for video ID uCfKLEaNYIc
# Saved data for video ID JLi5bgeFkbY
# Saved data for video ID 0hj2GRIALFs
# Saved data for video ID 0MQEt10e4NM
# Saved data for video ID OvWDxy5bme8
# Saved data for video ID SOc2Mm7OiNA
# Saved data for video ID gFUhxg2d_lM
# Saved data for video ID 5RwKwMQ9Rjg
# Saved data for video ID GMn_N043SGg
# Saved data for video ID ddnaaBCpAbU
# Saved data for video ID oTMPb8o2b1A
# Saved data for video ID JN7YV0v-OMI
# Saved data for video ID l5D4NijaEoA
# Saved data for video ID vAAyC-DOVBw
# Saved data for video ID l2iAqifHVAE
# Saved data for video ID stbRVl7iI9Q
# Saved data for video ID huByjM8T5X8
# Saved data for video ID oqi329rg9f4
# Saved data for video ID TRQXGEf6L8o
# Saved data for video ID XE9gn7gmbHo
# Saved data for video ID yPzHDHYqUMk
# Saved data for video ID hpnmZqOW2dU
# Saved data for video ID r6LbTzrE_58
# Saved data for video ID yqIH4K9IEHQ
# Saved data for video ID U2er2dsc9_U
# Saved data for video ID OL3ewwaMcVM
# Saved data for video ID DtsYfwl4uKw
# Saved data for video ID 1DFJ_A9JC68
# Saved data for video ID NykUD7FED2E
# Saved data for video ID 2QX_ECsZXp8
# Saved data for video ID uLs-EYUpGAw
# Saved data for video ID uNOd4K_HqjI
# Saved data for video ID 9AF5tReQ2ts
# Saved data for video ID JSJIolgFYqw
# Saved data for video ID 7Qv0cmJ6FsI
# Saved data for video ID Eft_S7yjLIQ
# Saved data for video ID OWyWevKhM0c
# Saved data for video ID fxOHbT9B4iA
# Saved data for video ID JiWVHYr9m8A
# Saved data for video ID C1vCS6_49FI
# Saved data for video ID vYBgYo22ZM0
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID uG5hcXgS9vw
# Saved data for video ID QnNOh-Wza_Q
# Saved data for video ID quqchM22pIk
# Saved data for video ID BPhrX0jOThU
# Saved data for video ID F3fGD33Ljaw
# Saved data for video ID ZTP6b3LaVGg
# Saved data for video ID ll-XBaah7fg
# Saved data for video ID Rlwwq-3nDyg
# Saved data for video ID xjfVcWMkpIQ
# Saved data for video ID wdVtiVx_mAk
# Saved data for video ID SZLj94ntAPU
# Saved data for video ID iMJZAWdQx7g
# Saved data for video ID Phm83k8fcoQ
# Saved data for video ID qB6739lRT-s
# Saved data for video ID A8auassRatE
# Saved data for video ID 6QV4vPpDxKQ
# Saved data for video ID AbR5X9bLZXw
# Saved data for video ID Xf1VnUTFX98
# Saved data for video ID uw4NtcTD4iM
# Saved data for video ID nGCZcuB5t8E
# Saved data for video ID XsqcHKf5LpI
# Saved data for video ID s8db5dvsEZ0
# Saved data for video ID F_AwZgtycII
# Saved data for video ID KcHhqPN-wVo
# Saved data for video ID KW1AGw1Wj9k
# Saved data for video ID Z2VXrwMYHFk
# Saved data for video ID mICySHB0fh4
# Saved data for video ID okqObNqpP2o
# Saved data for video ID gJX2jR0-PTY
# Saved data for video ID YRue69W-dYU
# Saved data for video ID dob9FQ5QrEo
# Saved data for video ID ahI28eFMcos
# Saved data for video ID P9CJYwOfULg
# Saved data for video ID YzCVUcDakVs
# Saved data for video ID TTlqECPvZpg
# Saved data for video ID ze-MSKcwlbk
# Saved data for video ID ZLmtEqWEHMg
# Saved data for video ID jZs5rX8Kl3o
# Saved data for video ID kMs1_IYhLwE
# Saved data for video ID m6P6oE5KDpo
# Saved data for video ID 2Pmf6Kqak3w
# Saved data for video ID 0Ds5AjZU88c
# Saved data for video ID iyTYW4cM5RQ
# Saved data for video ID 0SR5n6NuzIY
# Saved data for video ID dDFCFAy7d0k
# Saved data for video ID cLf_MKUbdqg
# Saved data for video ID XUED7kNL21I
# Saved data for video ID 19Z3aDMf8iI
# Saved data for video ID P-W9w6t3WCo
# Saved data for video ID EtBm5n-N0Qk
# Saved data for video ID ozWPxMsUvCI
# Saved data for video ID faw7qS67ee4
# Saved data for video ID oLp8OQKR_N0
# Saved data for video ID RvGgfU8PwM8
# Saved data for video ID X9S7HeP1rak
# Saved data for video ID t5_b-5faKQM
# Saved data for video ID prm_X9YMdPc
# Saved data for video ID skeLoUbC-1I
# Saved data for video ID uo6d1NfakP4
# Saved data for video ID RKwEalE44eQ
# Saved data for video ID mG5_TyFDtVE
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID yuihBbQChAU
# Saved data for video ID GxvGg_oyN1M
# Saved data for video ID NfPGFSUM-nI
# Saved data for video ID Gn6fPYD1oIU
# Saved data for video ID 1GB_JzOPH_E
# Saved data for video ID prJfAP2_YC8
# Saved data for video ID XdZq0CjQObY
# Saved data for video ID flVOgYS7cBo
# Saved data for video ID X-Y91ddBqaQ
# Saved data for video ID N7UlwJoxFI4
# Saved data for video ID 3iTDW3ZeWsc
# Saved data for video ID TsjXvANsN0c
# Saved data for video ID R4DHQs8hi0g
# Saved data for video ID oozTo8b6moA
# Saved data for video ID 1XqG0kaJVHY
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID DXTKLj3jb6Y
# Saved data for video ID PgOaCmwPbpw
# Saved data for video ID YyXP7yCfOIU
# Saved data for video ID qg_M37WGKG8
# Saved data for video ID 56ZFz6hcSJs
# Saved data for video ID nWmeC61DgBo
# Saved data for video ID PCWvSvlSMWU
# Saved data for video ID fBq-jSdtZjc
# Saved data for video ID hzGnnx0k6es
# Saved data for video ID KeXAWsnN2N4
# Saved data for video ID e27G-UCju0E
# Saved data for video ID AaN1zkQ7LpQ
# Saved data for video ID asW8tp1qiFQ
# Saved data for video ID m24ZPUOGXe4
# Saved data for video ID ePfX6a7rsis
# Saved data for video ID zlL8oLrOzQY
# Saved data for video ID U6cUekCbAJI
# Saved data for video ID 7J3mz9LMjqg
# Saved data for video ID YuxwkchSAW4
# Saved data for video ID QYcrjrwKswc
# Saved data for video ID OokRFFmUsz0
# Saved data for video ID _HkdhbSeG5g
# Saved data for video ID EgXQvvbmtnM
# Saved data for video ID NDtjbcTbjFE
# Saved data for video ID H1-6PfTovb8
# Saved data for video ID 8EvtpHeUwiw
# Saved data for video ID Qh7VxLsaU9M
# Saved data for video ID Lg2o7kIhhME
# Saved data for video ID ZcBL9_86YxY
# Saved data for video ID 4R8nWDh-wA0
# Saved data for video ID HatwtJSsj5Q
# Saved data for video ID YxrGCYwM-08
# Saved data for video ID xCNREN6UVbg
# Saved data for video ID 6vgKe5HIDqE
# Saved data for video ID 6CqRnx6Ic48
# Saved data for video ID vtuH4VRq1AU
# Saved data for video ID 03GNDapv-V4
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID QOvaBDwFLNA
# Saved data for video ID uPr6wryXJ3E
# Saved data for video ID DD5uwJINT98
# Saved data for video ID 4QTP5SI4oRM
# Saved data for video ID Mpi0405kN_M
# Saved data for video ID 6Rqc7JyCfJY
# Saved data for video ID 8JMOp-Q8xUM
# Saved data for video ID FCDJkxPd_3U
# Saved data for video ID ndnO6L-7YrU
# Saved data for video ID GiYomnW7zuM
# Saved data for video ID A2CNS2g_LXg
# Saved data for video ID 55IKVSB5AoM
# Saved data for video ID B5cP7pVVHQ0
# Saved data for video ID nzhSjOKSGC8
# Saved data for video ID 3mvtYH95LCw
# Saved data for video ID p8arik6ZyyI
# Saved data for video ID VASfvk3FH2k
# Saved data for video ID i-xmfYo68EI
# Saved data for video ID YeJchthNFLo
# Saved data for video ID bs6ic48kW6s
# Saved data for video ID nRLkdCiXHS0
# Saved data for video ID b8sfVEEZFmY
# Saved data for video ID 8PqY_Ev-r3I
# Saved data for video ID 9rxOHrL9IO8
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID l2CcR9zeKwc
# Saved data for video ID Eb8bQKyKJ6g
# Saved data for video ID _aOstSZxpeg
# Saved data for video ID 5hYb7IAjxp0
# Saved data for video ID T537o5tuY28
# Saved data for video ID J5ebCdGlcls
# Saved data for video ID iNncKbLKrjE
# Saved data for video ID ChBxx4aR-bY
# Saved data for video ID K4mlHMWm5ys
# Saved data for video ID njRYKzRKBPY
# Saved data for video ID XaPPdR0Gwcc
# Saved data for video ID tFB6_EIWYoU
# Saved data for video ID j4zoh8f-QaU
# Saved data for video ID shu4pYQb-ps
# Saved data for video ID 548PmNim5_E
# Saved data for video ID W-9tbdU_mgg
# Saved data for video ID S3C6f5GH2J8
# Saved data for video ID InYYArT_FMc
# Saved data for video ID dqVcmg6O0GQ
# Saved data for video ID EZOab1vkFmI
# Saved data for video ID Ohx74OCmeTQ
# Saved data for video ID 0l650D7EwOo
# Saved data for video ID pDaDbobxIkA
# Saved data for video ID 3Spa10-mwsw
# Saved data for video ID 1Azmr-wOeU0
# Saved data for video ID b3FI3WwXbYg
# Saved data for video ID VfC6xta9PFk
# Saved data for video ID IB9WfafBmjk
# Saved data for video ID yf6vr1zaq4Y
# Saved data for video ID 5W51LKz4Dkw
# Saved data for video ID PvTbAKkfLCc
# Saved data for video ID Q-FdHb-ZslQ
# Saved data for video ID ZavDzq5t_s4
# Saved data for video ID cqrImv8a_vc
# Saved data for video ID 0SKzmr_c2rA
# Saved data for video ID janjBPhzgyI
# Saved data for video ID ldXfjoL8st0
# Saved data for video ID 7qluYVHGKCs
# Saved data for video ID HeFajh2IQ9Q
# Saved data for video ID yWwHi8RTYnQ
# Saved data for video ID hJH6YQzk8gQ
# Saved data for video ID i7ZUW9UVUj8
# Saved data for video ID cUV-uNN5aEM
# Saved data for video ID rSQjUTIMizs
# Saved data for video ID YEwt6BJROug
# Saved data for video ID dBSvxM_k8E4
# Saved data for video ID OPgE-uc7jaQ
# Saved data for video ID EQpszzDHbo0
# Saved data for video ID U_7ICnt6QQ4
# Saved data for video ID 9pm3X-Qdadk
# Saved data for video ID a83EwoIPazg
# Saved data for video ID wphafs86Drc
# Saved data for video ID fePKBTMBbhw
# Saved data for video ID sAtnX3UJyN0
# Saved data for video ID m6FF69u6rRI
# Saved data for video ID sfLEBH6n99k
# Saved data for video ID 7v9k9YFy69U
# Saved data for video ID Qoh83xF2Trs
# Saved data for video ID 5mlth-yM2NE
# Saved data for video ID CIfZi0niNE0
# Saved data for video ID pBLG7_7aQ9I
# Saved data for video ID QFgI5rVQdbI
# Saved data for video ID CLoxiWsk-0c
# Saved data for video ID BMkkrQdsMhQ
# Saved data for video ID _aa3T-_MR9E
# Saved data for video ID QKp4hO0g1-k
# Saved data for video ID NhLgMqDY8MU
# Saved data for video ID E0ewe4m1OvA
# Saved data for video ID 78d0VNnlZ5w
# Saved data for video ID SrY0sTJchHE
# Saved data for video ID wULZ49c1atg
# Saved data for video ID tlv5iITsxIQ
# Saved data for video ID vDSwIarmbaM
# Saved data for video ID ZIXzR90pt2U
# Saved data for video ID hWMBwtVh2lg
# Saved data for video ID c0TGfNqw0ZE
# Saved data for video ID ruxaenl3Gtg
# Saved data for video ID BMvHOzDia_k
# Saved data for video ID Axyi1rB8yGs
# Saved data for video ID TLtx4ltEnEQ
# Saved data for video ID 7cg9HYKYO1A
# Saved data for video ID KgJNIMe4yVc
# Saved data for video ID _u2SSzC4wdo
# Saved data for video ID 9Mmj8NMCqEQ
# Saved data for video ID F-OQblAYnw0
# Saved data for video ID 5z0yspCeEMM
# Saved data for video ID ifX-oC8Yc5A
# Saved data for video ID 4jv1pUrG0Zk
# Saved data for video ID e9wUXTTlduQ
# Saved data for video ID rtO_02vRv8Q
# Saved data for video ID FllcPjvztTI
# Saved data for video ID EwY26ASJkQc
# Saved data for video ID Q8fut-j-l38
# Saved data for video ID FgakZw6K1QQ
# Saved data for video ID FD4DeN81ODY
# Saved data for video ID HMOI_lkzW08
# Saved data for video ID TJdH6rPA-TI
# Saved data for video ID ZgyY3JuGQY8
# Saved data for video ID 5vgP05YpKdE
# Saved data for video ID fkf4IBRSeEc
# Saved data for video ID g-Hb26agBFg
# Saved data for video ID I0ENqQ5e9KQ
# Saved data for video ID 8klqIM9UvAc
# Saved data for video ID Dv-Kk7PDEas
# Saved data for video ID pmG4K79DUoI
# Saved data for video ID dhK8nbtii6I
# Saved data for video ID rdzk7Ps7QFk
# Saved data for video ID 8CKsn2nauLU
# Saved data for video ID nEvKduLXFvk
# Saved data for video ID _UVHneBUBW0
# Saved data for video ID H99JRtDDnvk
# Saved data for video ID ZtS6sQUAh0c
# Saved data for video ID iRbsBi5W0-c
# Saved data for video ID dz8imS1vwIM
# Saved data for video ID Up46jS_Tb1s
# Saved data for video ID FyVCyjna97U
# Saved data for video ID kw9R0nD69OU
# Saved data for video ID JzVOU-AjpL8
# Saved data for video ID irA-NBq-lCk
# Saved data for video ID Wdi5ZgbFGo8
# Saved data for video ID RUP0_24eGn0
# Saved data for video ID _zJP3myOGtU
# Saved data for video ID kMaaktPjzAM
# Saved data for video ID 3J_wLxajcb4
# Saved data for video ID N-49t1j-XWY
# Saved data for video ID lb8-J4PREu0
# Saved data for video ID f0_UWY3R8CY
# Saved data for video ID n7npKX5zIWI
# Saved data for video ID hkCT-6KJAK0
# Saved data for video ID S51bTyIwxFs
# Saved data for video ID WCigXTRVH78
# Saved data for video ID OmaAC8a52YI
# Saved data for video ID ne6vnKoTHwk
# Saved data for video ID Mg2D-7f6X-M
# Saved data for video ID kApPBm1YsqU
# Saved data for video ID GSNPzboQEoM
# Saved data for video ID FMlas6P4YAQ
# Saved data for video ID h0yTEXlXuOY
# Saved data for video ID Yg1S8thAcWo
# Saved data for video ID _z21tse6kzo
# Saved data for video ID M6fBAzcw1Ps
# Saved data for video ID idp2vP3O52w
# Saved data for video ID osgqQy9Hr8s
# Saved data for video ID GkethEBRqy4
# Saved data for video ID 83x5X66uWK0
# Saved data for video ID Oi4SJqJIL2E
# Saved data for video ID sUpdplgmBb4
# Saved data for video ID bBNmfggp4wo
# Saved data for video ID BFdmXjs7l00
# Saved data for video ID VqjJ5YYt78Y
# Saved data for video ID n-N0D4uSgwM
# Saved data for video ID 9ncSCmluA5E
# Saved data for video ID QdBy02ExhGI
# Saved data for video ID uXe1CyIgNMw
# Saved data for video ID rdLWXIYpcBg
# Saved data for video ID 1U6SYVtGnD8
# Saved data for video ID MYiD0BjynSc
# Saved data for video ID 4zbUcgfycTU
# Saved data for video ID DlU5E3LD2Ck
# Saved data for video ID 5HNr_j6LmPc
# Saved data for video ID oiusrJ0btwA
# Saved data for video ID DBqIQsfTAww
# Saved data for video ID hnzW8UxQlvo
# Saved data for video ID wWt6cAHlDbg
# Saved data for video ID aUOV7EBGOy8
# Saved data for video ID sq-fNRGseEQ
# Saved data for video ID 6Id69voS-c8
# Saved data for video ID AoybgeddR1I
# Saved data for video ID qAtGPNMUoXo
# Saved data for video ID eAcYYH9pKQ4
# Saved data for video ID mCk8czlCikM
# Saved data for video ID d588GFOEnP0
# Saved data for video ID ZqXnPcyIAL8
# Saved data for video ID VvVwf4B0Xks
# Saved data for video ID Ack2sDP4gxo
# Saved data for video ID vFUvNICWVz4
# Saved data for video ID NIA51AqVsZ4
# Saved data for video ID M4HpyJHPYBY
# Saved data for video ID 3QwZ2GgHSLE
# Saved data for video ID 8gUQKAaoN7k
# Saved data for video ID L18Cd89kMRg
# Saved data for video ID fXYthdGwNcA
# Saved data for video ID wkHlKCm74CM
# Saved data for video ID CHDLeQxJqa8
# Saved data for video ID j7r-rhhU4nU
# Saved data for video ID hxpugUtCRx0
# Saved data for video ID YafpOzp88do
# Saved data for video ID jO8O61rj7sk
# Saved data for video ID B4G4iQUSCO0
# ...
# Saved data for video ID jzU917LzpUY
# Saved data for video ID h5odHn3MzPk
# Saved data for video ID Bjy81x3Efvk
# Saved data for video ID y1J6Q7xLwbk
# Saved data for video ID mXcPVtbB9pU
# Saved data for video ID E1jFY7uPg2U
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID XdPKBjWt3c8
# Saved data for video ID DyTMmvH41Oo
# Saved data for video ID AE5iRqaQnnM
# Saved data for video ID rA6l3zUEZ8c
# Saved data for video ID T4VEtaYTl1E
# Saved data for video ID Dwp2s2Qh6x0
# Saved data for video ID Hxy9CU9sqKs
# Saved data for video ID sLm_nLm0PGo
# Saved data for video ID HmDxN1U_ikM
# Saved data for video ID jJ-Sk_KZkmk
# Saved data for video ID cmXLhqv67ns
# Saved data for video ID FaL7skPxgMc
# Saved data for video ID smwYdFTYnFY
# Saved data for video ID wuM5lRUOijE
# Saved data for video ID H-hoJOCi-kc
# Saved data for video ID r7tzfm30SZc
# Saved data for video ID 6uY0f49P_0g
# Saved data for video ID QiLE6dcqwwY
# Saved data for video ID WTjK0OUr9us
# Saved data for video ID 37cierisyrE
# Saved data for video ID fwOf-eUOkag
# Saved data for video ID ld2K2CA1TYo
# Saved data for video ID rwF-X5STYks
# Saved data for video ID qYNweeDHiyU
# Saved data for video ID _6R7Ym6Vy_I
# Saved data for video ID 2IK3DFHRFfw
# Saved data for video ID hfIUstzHs9A
# Saved data for video ID G2fqAlgmoPo
# Saved data for video ID nW7btpcyNu0
# Saved data for video ID gCDacaohqaA
# Saved data for video ID 3on3S-fbeRI
# Saved data for video ID dFSnam97YbQ
# Saved data for video ID SCE3iKbXXTQ
# Saved data for video ID unPKJJjQP0A
# Saved data for video ID NRmAXDWJVnU
# Saved data for video ID 2p5OHDxR2l8
# Saved data for video ID 2kSl0xkq2lM
# Saved data for video ID cZaNf2rA30k
# Saved data for video ID 6de4akFiNYM
# Saved data for video ID pWNAtUwnBS8
# Saved data for video ID rAEqP9VEhe8
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID 9RvWcXVaAng
# Saved data for video ID dm3oPHFC6cY
# Saved data for video ID eJ0BfjH5_Js
# Saved data for video ID 0Ugz65i_nkI
# Saved data for video ID i7kE1kwTcRA
# Saved data for video ID 3YHtt7_9dBQ
# Saved data for video ID _kAN6Q8sESU
# Saved data for video ID n1jk_6taD74
# Saved data for video ID 3I-KNY3n9PU
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID tmB5JIX3Lxk
# Saved data for video ID tWhuUEjraKg
# Saved data for video ID HMRIEXAZV2o
# Saved data for video ID 9xVZ3For_fE
# Saved data for video ID HMQiaXxyC6o
# Saved data for video ID sws-oSfy534
# Saved data for video ID vktau4YRe9A
# Saved data for video ID WFEv9SeWiGw
# Saved data for video ID CHe3ofWbigQ
# Saved data for video ID saS-Co0uLXA
# Saved data for video ID QbP3Hca1Rl0
# Saved data for video ID gHXENP57beg
# Saved data for video ID hPrn6Smepbk
# Saved data for video ID laaBLUxJUMY
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID B2zCWJBnfuE
# Saved data for video ID SNZSm02_fpU
# Saved data for video ID 8BNo1sM7wFw
# Saved data for video ID g9F-_tCakL8
# Saved data for video ID C0BlPaeX4sA
# Saved data for video ID Yq0QkCxoTHM
# Saved data for video ID F0GQ0l2NfHA
# Saved data for video ID 7HgT-CBmKyE
# Saved data for video ID fN3gdUMB_Yc
# Saved data for video ID HEHUpBO8UVc
# Saved data for video ID MJQIQJYxey4
# Saved data for video ID DvBRj--sUMU
# Saved data for video ID vazwd0HOohE
# Saved data for video ID iHE9g4igyPg
# Saved data for video ID As3TT3xlddU
# Saved data for video ID d4yCWBGFCEs
# Saved data for video ID mEsleV16qdo
# Saved data for video ID xOS0BhhdUbo
# Saved data for video ID 3on3S-fbeRI
# Saved data for video ID 1fQ1DDMmiqo
# Saved data for video ID 5R8xZb6J3r0
# Saved data for video ID JO9MgO1Zp3E
# Saved data for video ID iXCqIpDZ_IY
# Saved data for video ID k7HaeJs-N-o
# Saved data for video ID lv7ka-8FscI
# Saved data for video ID CBhqnitNorI
# Saved data for video ID s4r5gXdSVPM
# Saved data for video ID Ch6KE7KxHGM
# Saved data for video ID FrDnPTPgEmk
# Saved data for video ID F8NKVhkZZWI
# Saved data for video ID Koe9-yV3p2w
# Saved data for video ID fBR42OxjWaM
# Saved data for video ID VZ98AbiopfM
# Saved data for video ID UOJO5pGiq6E
# Saved data for video ID uUxDYiXr9lA
# Saved data for video ID bc_0pn4OrDc
# Saved data for video ID 95G5j2FW5aM
# Saved data for video ID qJeaCHQ1k2w
# Saved data for video ID nxowuOht6ec
# Saved data for video ID X7Zd4VyUgL0
# Saved data for video ID 0xm0VZNjIsg
# Saved data for video ID kbG2CWrmKTw
# Saved data for video ID iOdFUJiB0Zc
# Saved data for video ID jLPgMnnp4Zo
# Saved data for video ID LFs2z7UUDJU
# Saved data for video ID bpOvayHifNQ
# Saved data for video ID Tnt-fiKdml0
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID E_Y7BarscHA
# Saved data for video ID h8wTc1lBQ7g
# Saved data for video ID hHnvo4f35GA
# Saved data for video ID 9VPvfFs73zc
# Saved data for video ID s1fhxAVpYx8
# Saved data for video ID 9e_Bum8FMMs
# Saved data for video ID BGk0decZhL8
# Saved data for video ID RWkjBtMmKTU
# Saved data for video ID 5Th-DKQh88o
# Saved data for video ID VT6lAz3yp1U
# Saved data for video ID _Ahl73azv7U
# Saved data for video ID j3DsRK0IBfs
# Saved data for video ID ez2ysHFCc1s
# Saved data for video ID eXk5fV921yQ
# Saved data for video ID KU_2l0cuFtY
# Saved data for video ID mE24ly1jNJM
# Saved data for video ID GKOoIqoqCxc
# Saved data for video ID kqfpcJnWJaE
# Saved data for video ID ZXiruGOCn9s
# Saved data for video ID dFSnam97YbQ
# Saved data for video ID kpjqxalCKdg
# Saved data for video ID ONMftqeKZRE
# Saved data for video ID YVd2uQwxULc
# Saved data for video ID nSQrY-uPWLY
# Saved data for video ID vf93B08v7Qs
# Saved data for video ID 2HYUhv_3D6s
# Saved data for video ID 6l0x4qvrnqI
# Saved data for video ID vncGZ1j353w
# Saved data for video ID V2nSbrdEpUE
# Saved data for video ID VkGYCHHUo84
# Saved data for video ID unKXfaxVRCk
# Saved data for video ID nwxtEvljUZU
# Saved data for video ID ajWheP8ZD70
# Saved data for video ID dBEPTRoMKKg
# Saved data for video ID SCE3iKbXXTQ
# Saved data for video ID soFXIJj81hE
# Saved data for video ID ETMdk-b1Z94
# Saved data for video ID z7-fPFtgRE4
# Saved data for video ID gNiZluuE274
# Saved data for video ID fwaDtRbfioU
# Saved data for video ID qtuzVc0N5o0
# Saved data for video ID 88raFDgLvFc
# Saved data for video ID P2Vege6NtW0
# Saved data for video ID xjveLQ-FHXg
# Saved data for video ID Do60mT2tS5U
# Saved data for video ID KWkMavHcC4M
# Saved data for video ID rgyYyy85Kdo
# Saved data for video ID WNsJNIVALwY
# Saved data for video ID y9s-wFhEzTw
# Saved data for video ID TTcR4Hgoxxw
# Saved data for video ID om7iYSucLrk
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID baYKwwZx-CQ
# Saved data for video ID qrQZRXeY9_E
# Saved data for video ID KrRD7r7y7NY
# Saved data for video ID jKW7QqUhz8g
# Saved data for video ID 8OQbQv5W-BU
# Saved data for video ID 7l0G_awxFg0
# Saved data for video ID w4FXVjlYqW4
# Saved data for video ID NB6xXwvhKJI
# Saved data for video ID j8Lq6tpJjnE
# Saved data for video ID IVmpJREOtbg
# Saved data for video ID cN1PxxQWoEc
# Saved data for video ID _lcJug_w0Uc
# Saved data for video ID 8OHe-4aYiKo
# Saved data for video ID vW9fIro6N6g
# Saved data for video ID 5l7Tw6UVQi8
# Saved data for video ID nVyD6THcvDQ
# Saved data for video ID io6JqPG80WU
# Saved data for video ID f9V87NftLBA
# Saved data for video ID JXou0zC4c4c
# Saved data for video ID 2xF665jzO9Q
# Saved data for video ID 72Wtc6c-aI4
# Saved data for video ID CFrziAQ85WE
# Saved data for video ID jWO7oLrH22o
# Saved data for video ID Oh8cojceKoQ
# Saved data for video ID ZJ6VYuVyiXM
# Saved data for video ID L9-47sX8PvI
# Saved data for video ID WOsI54g7FVc
# Saved data for video ID hJP5GqnTrNo
# Saved data for video ID PVVUPUJeezo
# Saved data for video ID v1pj9XrJ_Lw
# Saved data for video ID 6pftbnNQlb8
# Saved data for video ID 4A4W03qUTsw
# Saved data for video ID nV1ifeTBAiA
# Saved data for video ID 7eQV2UZ24Nc
# Saved data for video ID X1rw_iHzxtk
# Saved data for video ID gGK7b7j4BiQ
# Saved data for video ID BLv8ISZ_Sww
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID y4SLh1cpap4
# Saved data for video ID DU0IeYwVJHg
# Saved data for video ID puvAuPJesg8
# Saved data for video ID 9T9pTIfGgbo
# Saved data for video ID WUBl6SMRy0g
# Saved data for video ID DXLHaLua-Mw
# Saved data for video ID TOPaqzM7u5s
# Saved data for video ID Na5HjNLv9_Y
# Saved data for video ID pSVk-5WemQ0
# Saved data for video ID _vTV0TEj4BI
# Saved data for video ID bTkUTkXrqOQ
# Saved data for video ID kY7ak0p4tZM
# Saved data for video ID K8MSDBqLBMA
# Saved data for video ID b8UPWzS7KS8
# Saved data for video ID bHkSKRQUEvE
# Saved data for video ID UrC6jZJdVXk
# Saved data for video ID bd505-daMrw
# Saved data for video ID X1Ek2Hs6MCs
# Saved data for video ID 48ccog80PNA
# Saved data for video ID HdafI0t3sEY
# Saved data for video ID 9FxWldwS-JQ
# Saved data for video ID p09yRj47kNM
# Saved data for video ID Fe3XOnyNwW4
# Saved data for video ID vUsBnx5rNzA
# Saved data for video ID nCglvjJkU8A
# Saved data for video ID kp2z-wytZx8
# Saved data for video ID bZzyPscbtI8
# Saved data for video ID tiNlTvpCKT8
# Saved data for video ID 0iJJmvgj4dc
# Saved data for video ID vOrhfyMe_EQ
# Saved data for video ID bTLaTvbi9vM
# Saved data for video ID SeuS84YeJVc
# Saved data for video ID gMa_QHSAxOY
# Saved data for video ID SQUZpnJpDI8
# Saved data for video ID juPLIubS-ec
# Saved data for video ID 3ENnyP7iM1E
# Saved data for video ID Q_fXNer4ENg
# Saved data for video ID 0TCYAafJgRE
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID AXj3XT86nhI
# Saved data for video ID ROqB8xhKZ6U
# Saved data for video ID CdcsjDSHpgA
# Saved data for video ID SQb5-W8TZYk
# Saved data for video ID nJ25yl34Uqw
# Saved data for video ID iG4WeUj5eBA
# Saved data for video ID _ZvnD73m40o
# Saved data for video ID 0GjK1rvuI1Q
# Saved data for video ID nOWHISbQeH4
# Saved data for video ID F9LGHxDHUlU
# Saved data for video ID 3fTv_uXr5oQ
# Saved data for video ID RLdD831I8hk
# Saved data for video ID ZCX-gT1q0ZQ
# Saved data for video ID FLUyLqGlW2s
# Saved data for video ID LGgccYDyGFk
# Saved data for video ID XDged1ZBFCU
# Saved data for video ID fQITLL5WncE
# Saved data for video ID 0R1mA_MVItI
# Saved data for video ID S-sGtdUfaoQ
# Saved data for video ID bnQ2SwHC-Fs
# Saved data for video ID N0PvUG7nSGk
# Saved data for video ID lbbYM2xeNTA
# Saved data for video ID _13WrpPvtf4
# Saved data for video ID LDOFrBnaS0o
# Saved data for video ID JZKMi0n6FF4
# Saved data for video ID H_OUNbgMe_Y
# Saved data for video ID EvOhw-GTomY
# Saved data for video ID i268oenkv0U
# Saved data for video ID zaXJpfUlrqI
# Saved data for video ID swCPic00c30
# Saved data for video ID blmnQN7YY00
# Saved data for video ID Oqz2PjPeyi4
# Saved data for video ID SW7zE4GnVqA
# Saved data for video ID tuvi4BmXR5s
# Saved data for video ID CLJpJJnq5M8
# Saved data for video ID RJMffQ7NWtg
# Saved data for video ID _3ezSpJw2E8
# Saved data for video ID RUPBK6k5Xdc
# Saved data for video ID 15EJ929GrEA
# Saved data for video ID kK10CU26t6Q
# Saved data for video ID CB4pDXAnmME
# Saved data for video ID cHzL_X23ywY
# Saved data for video ID 7Jd-Rr9cJYo
# Saved data for video ID yojXEPwcTJE
# Saved data for video ID W60Nh2e6Q8g
# Saved data for video ID rdhANCDfFBE
# Saved data for video ID HlAjRm6S4VU
# Saved data for video ID cQUUkZnyoD0
# Saved data for video ID FdRJd6OGgGI
# Saved data for video ID 4S7S_JMp3bE
# Saved data for video ID xQXabrbvlAo
# Saved data for video ID EkF2wvflRns
# Saved data for video ID L86RHwzqN7g
# Saved data for video ID _tESQLUw03g
# Saved data for video ID SZQV9-s8w94
# Saved data for video ID sJyuPK945C8
# Saved data for video ID C66HkH6a2cE
# Saved data for video ID gy1h_sn7Myo
# Saved data for video ID 5B_qVY3lWz4
# Saved data for video ID bdICz_sBI34
# Saved data for video ID jvEum8V-M1M
# Saved data for video ID LlWDx0LSDok
# Saved data for video ID WIF7YjXLLlM
# Saved data for video ID axYzQ7yS_NY
# Saved data for video ID HZYBj-zeUlY
# Saved data for video ID MbnuZRgAN8E
# Saved data for video ID KZ-OVBT_3zM
# Saved data for video ID pcszga38uFc
# Saved data for video ID 59ht-yPmeKg
# Saved data for video ID ejhWG7ajbGE
# Saved data for video ID Gxc7pDDbn7U
# Saved data for video ID E0Pd8mUpr-M
# Saved data for video ID GCoP2w-Cqtg
# Saved data for video ID 2IS1an92HWA
# Saved data for video ID wgui8N3uzcs
# Saved data for video ID v_lhMrn0Sts
# Saved data for video ID QLF43kkNxeU
# Saved data for video ID QNiMzCfjG1o
# Saved data for video ID LTUNVqxv3Ro
# Saved data for video ID vLYtDgs_zx8
# Saved data for video ID wxokeVkCuVs
# Saved data for video ID FhKDn5CvN54
# Saved data for video ID wjZofJX0v4M
# Saved data for video ID yCezs53-DNE
# Saved data for video ID 8NjIihHQrxM
# Saved data for video ID 3eT5gjnNgUI
# Saved data for video ID 8-s38NrFLK4
# Saved data for video ID 0JTzrYarcJw
# Data fetching complete. Results saved to response_data.csv

# %%
import pandas as pd
df = pd.read_csv("response_data.csv", )

df.dropna()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("response_data.csv", )
#       4 df.dropna()
#
# File c:\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Python312\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Python312\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf0 in position 111493: invalid continuation byte

# %%
with open("response_data.csv", "rb") as f:
    content = f.read()

# Find the position of the problematic byte
problematic_byte_position = 111493  # Replace this with the position from the error message
print(content[problematic_byte_position - 10:problematic_byte_position + 10])  # Print surrounding bytes
# Out:
# b'nce is made for ""fa'
