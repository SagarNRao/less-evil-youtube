# %%
import pandas as pd
import requests
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

# Load the CSV file
df = pd.read_csv("heriobeans.csv")

# Create an empty DataFrame to store the results
savedf = pd.DataFrame()

# Collect all video IDs
idArray = df['id'].astype(str).tolist()

# API_KEY = os.getenv("API_KEY")
API_KEY = "AIzaSyBCQnr8GmsG35VdPP4bh6H9cD6cmlQpqFo"

output_file = "mathsNew.csv"

savedf.to_csv(output_file, index=False)

for video_id in idArray:
    url = f'https://youtube.googleapis.com/youtube/v3/videos?part=topicDetails,snippet&id={video_id}&key={API_KEY}'
    response = requests.get(url)

    if response.status_code == 200:
        api_data = response.json()
        if 'items' in api_data and len(api_data['items']) > 0:
            item = api_data['items'][0]

            video_data = {
                'video_id': video_id,
                'title': item['snippet']['title'] if 'snippet' in item else None,
                'description': item['snippet']['description'] if 'snippet' in item else None,
                'channel_name': item['snippet']['channelTitle'] if 'snippet' in item else None,
                'channel_id': item['snippet']['channelId'] if 'snippet' in item else None,
                'tags': ', '.join(item['snippet'].get('tags', [])) if 'snippet' in item else None,
                'topic_details': ', '.join(item['topicDetails'].get('topicCategories', [])) if 'topicDetails' in item else None
            }

            video_df = pd.DataFrame([video_data])

            video_df.to_csv(output_file, mode='a', header=False, index=False)
            print(f"Saved data for video ID {video_id}")
        else:
            empty_data = {
                'video_id': video_id,
                'title': None,
                'description': None,
                'channel_name': None,
                'channel_id': None,
                'tags': None,
                'topic_details': None
            }
            empty_df = pd.DataFrame([empty_data])
            empty_df.to_csv(output_file, mode='a', header=False, index=False)
            print(f"No data found for video ID {video_id}")
    else:
        empty_data = {
            'video_id': video_id,
            'title': None,
            'description': None,
            'channel_name': None,
            'channel_id': None,
            'tags': None,
            'topic_details': None
        }
        empty_df = pd.DataFrame([empty_data])
        empty_df.to_csv(output_file, mode='a', header=False, index=False)
        print(f"Failed to fetch data for video ID {video_id}: {response.json()}")

print("Data fetching complete. Results saved to response_data.csv")
# Out:
# Saved data for video ID WqRPFvZWF0k
# Saved data for video ID JTVNUdL7sWs
# Saved data for video ID yMs3K_NUyz4
# Saved data for video ID vOTTuZflAIM
# Saved data for video ID aesw9FeSXjI
# Saved data for video ID 5Mp04Tg2-u4
# Saved data for video ID ZF17di7Tcz0
# Saved data for video ID T1PEinfzJKA
# Saved data for video ID KnMRJLb6QjA
# Saved data for video ID 9hxrh6ToKjM
# Saved data for video ID 40XRHIgbwpQ
# Saved data for video ID BAH8uDH83HI
# Saved data for video ID m4ivJmRuPgE
# Saved data for video ID FEwNJ2HFsB4
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID Vjg77ncz-hk
# Saved data for video ID jOETy4rN-OY
# Saved data for video ID RGjs7xmYxrQ
# Saved data for video ID h-_-qyrYcP8
# Saved data for video ID laLXrou1VTY
# Saved data for video ID Qu4LN5i7__A
# Saved data for video ID F1sQoFaTlj4
# Saved data for video ID QdlypsJsAs0
# Saved data for video ID xvnAkAiHQRM
# Saved data for video ID VdYyuDiW8sY
# Saved data for video ID 8u6woY05aL0
# Saved data for video ID 1VUavSfYsvw
# Saved data for video ID eyyZsQOIme0
# Saved data for video ID HMj8PE-u74Q
# Saved data for video ID aoMN5nzl9zE
# Saved data for video ID ag3pwWxZO_s
# Saved data for video ID jAMKW7uiqWE
# Saved data for video ID NBYGYZhxiBY
# Saved data for video ID D4FvYWLVR0U
# Saved data for video ID dqtHaie-dEs
# Saved data for video ID LgRlxZNwp1c
# Saved data for video ID 2V-AhNrH5M0
# Saved data for video ID eeId8CmC7GU
# Saved data for video ID M04CmHi88N8
# Saved data for video ID Lrqef5Kp9YI
# Saved data for video ID 2XEI9I7yu38
# Saved data for video ID Uy2HEJeHWZ0
# Saved data for video ID e7HymUbfpRE
# Saved data for video ID QthW88icNQE
# Saved data for video ID 8jPEpQyVLXM
# Saved data for video ID FuMWdK8BO0w
# Saved data for video ID nQrVh3uHghM
# Saved data for video ID cG2Fs-cccpk
# Saved data for video ID HQRb-_RVDN4
# Saved data for video ID MtsOlAxZ6Q0
# Saved data for video ID wDquyccgrHA
# Saved data for video ID lafYTeO2wqM
# Saved data for video ID rZyWCq6ULcA
# Saved data for video ID YreZvGn14uY
# Saved data for video ID vcP3K-lGUk4
# Saved data for video ID Yz1m08YsD7k
# Saved data for video ID 0Frz1GMJmjQ
# Saved data for video ID tOn7ZSAntKs
# Saved data for video ID bHf2-QlPYG4
# Saved data for video ID hfkgjFf2vLU
# Saved data for video ID B1vmsI1Z354
# Saved data for video ID 56hn-UAOTIg
# Saved data for video ID ZkERGBHbpCU
# Saved data for video ID 9Ki0OuoTptM
# Saved data for video ID H4w9Eq406Tg
# Saved data for video ID ngExcVgErKc
# Saved data for video ID d1Ovepemxk4
# Saved data for video ID PkloOaczh50
# Saved data for video ID 5U3eTYndDZA
# Saved data for video ID 766490Oh9NM
# Saved data for video ID KAIHn_inzR8
# Saved data for video ID Qa4DHBHtcps
# Saved data for video ID 0oUe0dvSHx0
# Saved data for video ID 5L95xFvi0yQ
# Saved data for video ID nMo69DkgN9k
# Saved data for video ID P77Gfyyfa3I
# Saved data for video ID 1IcBGRaDfIs
# Saved data for video ID E9cyo5Uxhmg
# Saved data for video ID CZ_08FFFzSM
# Saved data for video ID iFwgAwUFo6Q
# Saved data for video ID jrWq9wstObo
# Saved data for video ID ia8Nq3lTcys
# Saved data for video ID EPC729tdAqQ
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID V7P2LEmivLw
# Saved data for video ID m4GeiEsEzXk
# Saved data for video ID 5CluBRnu30g
# Saved data for video ID JUVf7CPaFgs
# Saved data for video ID oRalfmDOfIo
# Saved data for video ID SDP6lh9O0JI
# Saved data for video ID VIT_-rDaIeg
# Saved data for video ID cK8PteZ4NLo
# Saved data for video ID XjuyNjKEAcg
# Saved data for video ID 2DP1K6WBGZw
# Saved data for video ID KyKp8yRx3rE
# Saved data for video ID Kt9tTSfjcW8
# Saved data for video ID 0ymKfV8vMMw
# Saved data for video ID XvUjjo27_9I
# Saved data for video ID Y52_GoNjkIQ
# Saved data for video ID oUo4s7tfdZY
# Saved data for video ID cCRuSPnB1AU
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID vSg1OxR5D7M
# Saved data for video ID TFurX7Umx7w
# Saved data for video ID tgMRQ-4beTc
# Saved data for video ID ryq76Z6nJwM
# Saved data for video ID WPC06eDHVXw
# Saved data for video ID guy8xnByO04
# Saved data for video ID ueRM6P959oc
# Saved data for video ID 78AYOJExQSE
# Saved data for video ID S3MHRS_cZIc
# Saved data for video ID JOu2VHktyDg
# Saved data for video ID ohSBtrzEhWo
# Saved data for video ID wvebf65nZqI
# Saved data for video ID P0A3JrWlgBU
# Saved data for video ID d38vYbxrKRc
# Saved data for video ID o-O1d97k0zU
# Saved data for video ID dqGAqYuWePs
# Saved data for video ID KZSVIwCvtmA
# Saved data for video ID RI5egt8GhtE
# Saved data for video ID q-ByBIx9-sc
# Saved data for video ID gaPAVXmNrSg
# Saved data for video ID 3pfYQqP2cao
# Saved data for video ID Q37uxUdyEKU
# Saved data for video ID LhsLKjaAXfI
# Saved data for video ID ogTVJPf2XiQ
# Saved data for video ID bIwhIKLxfvo
# Saved data for video ID ztmmtrQB1Zg
# Saved data for video ID iC3rH-8Unyk
# Saved data for video ID FCkNPp59dcQ
# Saved data for video ID QoC42XF3beA
# Saved data for video ID aMyf1kRwFlM
# Saved data for video ID 0pcBRGFwx2M
# Saved data for video ID u4O-dk4yoKA
# Saved data for video ID eYVIPGBOWQ0
# Saved data for video ID hONWUC4sn4U
# Saved data for video ID qrUnUIEzHc8
# Saved data for video ID qDKTsQDH0rE
# Saved data for video ID aZwgY__iEaw
# Saved data for video ID zZsqk8wwveM
# Saved data for video ID 4_pgd8f1Mvs
# Saved data for video ID EQZ9qh8akeo
# Saved data for video ID Gkk6WilO_gs
# Saved data for video ID d7c7vPz25_A
# Saved data for video ID vBLOXIfqEJ0
# Saved data for video ID J3PMWxrZKY0
# Saved data for video ID BObezLecGNc
# Saved data for video ID q10KxBh2QtE
# Saved data for video ID QP-mPEIspDQ
# Saved data for video ID EFxv2r9gwtc
# Saved data for video ID T2R3Qp3zt5k
# Saved data for video ID iq81zaIyd2k
# Saved data for video ID t74lu82FrNc
# Saved data for video ID crHWbnODLk8
# Saved data for video ID gFa7ipk31-0
# Saved data for video ID lhZu62CVBgk
# Saved data for video ID 7skAg0v5t0A
# Saved data for video ID bVM480qC2kc
# Saved data for video ID uAOuFbUe4FI
# Saved data for video ID D9oEk98xdlM
# Saved data for video ID adXrLTsCr_8
# Saved data for video ID -1uK-fnSPO0
# Saved data for video ID 448iaucumPk
# Saved data for video ID b-mO0_9cMPo
# Saved data for video ID 3o8az6OHEmo
# Saved data for video ID hp2-6cFUwRI
# Saved data for video ID BxOYkxgW4kw
# Saved data for video ID fsJ3L65lEok
# Saved data for video ID 3423bi68F8Y
# Saved data for video ID NOaJFXeHoRE
# Saved data for video ID U54KLWzXwvw
# Saved data for video ID ptK6aS_h9-A
# Saved data for video ID 81orUHA37PQ
# Saved data for video ID 4ldHdfiEP-I
# Saved data for video ID 5MoLmtcWf84
# Saved data for video ID OggIpA5mugE
# Saved data for video ID Nokgkwd4mEw
# Saved data for video ID chj21mcyolY
# Saved data for video ID TvorEZ7PMis
# Saved data for video ID Vr3Pvp9rdUc
# Saved data for video ID UaDS1pMgiGU
# Saved data for video ID O76LO9-0wf4
# Saved data for video ID lwGUbJ0vkOg
# Saved data for video ID oC6pVnZA-zM
# Saved data for video ID 2dNKgt3Ma5A
# Saved data for video ID emdpMryH80M
# Saved data for video ID EguwBLUO8Ms
# Saved data for video ID _OocXJWp724
# Saved data for video ID dyegLOsz24U
# Saved data for video ID nJ0QtilaMnQ
# Saved data for video ID V3p5Lii5g8U
# Saved data for video ID aJj79nhlXdo
# Saved data for video ID uWwerv9IXn4
# Saved data for video ID vXn2GUZGFwA
# Saved data for video ID fkUrlOQ1xm4
# Saved data for video ID rdvmAqMQGPk
# Saved data for video ID M7uZWeYBLkE
# Saved data for video ID 3k4y6K7v2rM
# Saved data for video ID hBj2X7mx-nY
# Saved data for video ID ZaRNeJQZhWA
# Saved data for video ID WbtaJEBHMzw
# Saved data for video ID w7XysXJUPhU
# Saved data for video ID b0f7tGuda94
# Saved data for video ID BeIrYruuoF4
# Saved data for video ID vmbGWazo00s
# Saved data for video ID dvWV53foJ5w
# Saved data for video ID XWdnmKLObcQ
# Saved data for video ID 1YW975RayeM
# Saved data for video ID ef-xDjGNUG8
# Saved data for video ID kaZn14BdIM4
# Saved data for video ID LAq2jdo-Ci0
# Saved data for video ID KzoKD8xeleA
# Saved data for video ID Jk1JaDoZ8_I
# Saved data for video ID 69oFPiC_KTU
# Saved data for video ID yPH6_nHBHzU
# Saved data for video ID GHUXSoqp_Hg
# Saved data for video ID IROV-ZHxI_Q
# Saved data for video ID 3FtvM49V4WQ
# Saved data for video ID h7JgSZrHukI
# Saved data for video ID rrRKVyifhfo
# Saved data for video ID sJL7BvxWHGA
# Saved data for video ID 8NNsn1jhlsc
# Saved data for video ID 6omBH5R5fs8
# Saved data for video ID nsYy-M9P9Zo
# Saved data for video ID m12da3uwkIs
# Saved data for video ID DBLeZmWYAlk
# Saved data for video ID t0ykMtpUppo
# Saved data for video ID yHqaTzsMaAc
# Saved data for video ID IHEgk-V8Sj0
# Saved data for video ID SZY_r1eZuPs
# Saved data for video ID JX7pS5OHTy8
# Saved data for video ID TkjGZa1FBlg
# Saved data for video ID k1pj8KiYUF0
# Saved data for video ID vEaItutXM2Q
# Saved data for video ID 3S4iMXI49qg
# Saved data for video ID SXBsqXBAr08
# Saved data for video ID jX7pKEMG-A0
# Saved data for video ID cR8E9KpMQ6U
# Saved data for video ID 20ypH2SL2ds
# Saved data for video ID QPeJg7z_tTg
# Saved data for video ID Qsnz0UgqzpE
# Saved data for video ID d5b7LftE5Uc
# Saved data for video ID FtWqTkrbZUY
# Saved data for video ID tVDbPv7r8J4
# Saved data for video ID 1xot8RMxwms
# Saved data for video ID PTWsY2RhhZM
# Saved data for video ID fAU9Z82xKUI
# Saved data for video ID wZKJ7Q-PqvE
# Saved data for video ID yMe0BdQ0IIQ
# Saved data for video ID 0gGDG7liQdE
# Saved data for video ID OIpKbOATs6Y
# Saved data for video ID 65P2-DKQ4dI
# Saved data for video ID gMmyZ3opusc
# Saved data for video ID ewPn3OBn8EY
# Saved data for video ID m4ih3ps3pl4
# Saved data for video ID BUQJmITEbOc
# Saved data for video ID NVaOe_kAN7w
# Saved data for video ID kZOgLHdlIXk
# Saved data for video ID vxmwZJPMbM0
# Saved data for video ID hLhGo3P4D0c
# Saved data for video ID oRUj_-qogs4
# Saved data for video ID AAwnUylL-bk
# Saved data for video ID Z7HKsLyAZS4
# Saved data for video ID ptma8CAyQjg
# Saved data for video ID 200h2j4GQM8
# Saved data for video ID li76oz7pDww
# Saved data for video ID DUZW61Mx9fc
# Saved data for video ID kWdSMxDWspw
# Saved data for video ID Y_yiOM1BSKc
# Saved data for video ID SGmdUhrZUoA
# Saved data for video ID 15awMHeP1Yc
# Saved data for video ID otZDmDORP_I
# Saved data for video ID fCwERLMYTHY
# Saved data for video ID ajo6_vCLcv0
# Saved data for video ID dMEBMw91ZLM
# Saved data for video ID MUdFi1IGnEA
# Saved data for video ID TzEczTPioPc
# Saved data for video ID gbjjC5G9KFs
# Saved data for video ID RrTakZRcNbk
# Saved data for video ID hzM-tPzi25Y
# Saved data for video ID Jvm8LwJDCDY
# Saved data for video ID gW4efm1aG5k
# Saved data for video ID EyEaKmYhUe0
# Saved data for video ID 0NnOeFMADy4
# Saved data for video ID ZRbGZ4nu140
# Saved data for video ID AvQgLPLtaZ4
# Saved data for video ID MQOmz-5PV44
# Saved data for video ID UX58fA8KTYw
# Saved data for video ID ZtFoJ7JOzWI
# Saved data for video ID w-5J93tHOcQ
# Saved data for video ID UhfkW2kNedg
# Saved data for video ID VbW-bEINvAU
# Saved data for video ID EDnI6BP6_Xw
# Saved data for video ID 0Fx6jec8SwY
# Saved data for video ID kCm71AnpYiQ
# Saved data for video ID H2LeD0ktdXg
# Saved data for video ID FJlKsNK8h4s
# Saved data for video ID UMDzKAm2FR0
# Saved data for video ID numWVQ4f11Y
# Saved data for video ID 4DKXovl1mYs
# Saved data for video ID pGDpAM5ZAcg
# Saved data for video ID dGx3Tk_j0rY
# Saved data for video ID HryLDwBh9o4
# Saved data for video ID NM7CkwTkB-A
# Saved data for video ID zM4C07c3ZOk
# Saved data for video ID 4ZXH7nH-nd4
# Saved data for video ID rZ58r0G5TXo
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID R-uXiPGmXQ4
# Saved data for video ID DLpFS7k_f3w
# Saved data for video ID q1u-oa8LswA
# Saved data for video ID guy8xnByO04
# Saved data for video ID jA4VFB46v1E
# Saved data for video ID uMdP-VTEC38
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID B4INadyEzqo
# Saved data for video ID modQJEIURt8
# Saved data for video ID Ioov1l4mq7w
# Saved data for video ID or2W_iL4Fwg
# Saved data for video ID bLyMizOMUd0
# Saved data for video ID 0SD9ZS4gbx4
# Saved data for video ID jHLvPtjoSPQ
# Saved data for video ID pp8jtlPkbIw
# Saved data for video ID HHTQlYYk_Gc
# Saved data for video ID N2PpRnFqnqY
# Saved data for video ID gCHiLLgO55o
# Saved data for video ID tYkqwIllFX4
# Saved data for video ID nf9ByTdX0aY
# Saved data for video ID 9vKqVkMQHKk
# Saved data for video ID 5yfh5cf4-0w
# Saved data for video ID P8_KCItuZVM
# Saved data for video ID KAEOQ76BLLM
# Saved data for video ID gZB4RvZxvaI
# Saved data for video ID 74RG-PgPdbc
# Saved data for video ID ZSJeWfOFKZw
# Saved data for video ID FLAm7Hqm-58
# Saved data for video ID Ud_aN6TXuhk
# Saved data for video ID S0_qX4VJhMQ
# Saved data for video ID 4vns9LEbEj0
# Saved data for video ID fGYgiZd9dUw
# Saved data for video ID LQrBzl0DMBA
# Saved data for video ID QfvJojTymqs
# Saved data for video ID T_I-CUOc_bk
# Saved data for video ID DEhc-WrlBdA
# Saved data for video ID WHjOiYCR5Gs
# Saved data for video ID Xzdugb1Ds3I
# Saved data for video ID G2Px5w4J9Vk
# Saved data for video ID Pk476beQai0
# Saved data for video ID T8YrEDDPgW8
# Saved data for video ID hXSKsbVXnuI
# Saved data for video ID jfvL4CDFOtU
# Saved data for video ID s63nolrq5Kw
# Saved data for video ID 43pONQD86R4
# Saved data for video ID K4qHtLoVJmY
# Saved data for video ID dcqx4tRdsz4
# Saved data for video ID jsH4mpAsBOU
# Saved data for video ID HjVupOWFCB8
# Saved data for video ID dxGlH45XYUk
# Saved data for video ID Wjlw7ZpZVK4
# Saved data for video ID 3NQ9Luk9FHM
# Saved data for video ID EzePYR390dw
# Saved data for video ID DEhc-WrlBdA
# Saved data for video ID T_I-CUOc_bk
# Saved data for video ID F9KaHqG2RRY
# Saved data for video ID MDqD_O0BZG4
# Saved data for video ID Kp7sSp5Kn7o
# Saved data for video ID x3iEEDxrhyE
# Saved data for video ID B0jeGk5GJX0
# Saved data for video ID wUZcIYx-7a4
# Saved data for video ID ObHJJYvu3RE
# Saved data for video ID ZOdVGAcqfHg
# Saved data for video ID 3kDx3rkR4E4
# Saved data for video ID I2upuDqwv0c
# Saved data for video ID 8rt5BJyiDHA
# Saved data for video ID 43gkb-L9LBw
# Saved data for video ID aZSI4deUKWM
# Saved data for video ID rAof9Ld5sOg
# Saved data for video ID fiVgwEgc-DY
# Saved data for video ID ikSwHKQvp6I
# Saved data for video ID cD75mrF6gFA
# Saved data for video ID yJD7FekLzUg
# Saved data for video ID HaHsqDjWMLU
# Saved data for video ID RMoebmYqT5E
# Saved data for video ID wCZ1VEmVjVo
# Saved data for video ID 0xO5dBja118
# Saved data for video ID PBEeD9q25O4
# Saved data for video ID Za3-2qYkTR8
# Saved data for video ID Q0Qe352nhxU
# Saved data for video ID 2kyQ1YuzOBM
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID IvLpN1G1Ncg
# Saved data for video ID SqCoKKg5yQI
# Saved data for video ID kfF40MiS7zA
# Saved data for video ID THk57jDdZSw
# Saved data for video ID qPhLWfn-t_4
# Saved data for video ID WsQQvHm4lSw
# Saved data for video ID G03GZuPp3FQ
# Saved data for video ID QqF3i1pnyzU
# Saved data for video ID 17X5g9QArTc
# Saved data for video ID 962lLfW-8Jo
# Saved data for video ID Tilbn1qqTw0
# Saved data for video ID WUvTyaaNkzM
# Saved data for video ID qBAq5N4wT5M
# Saved data for video ID I2uIH-KdITk
# Saved data for video ID LkcbabVODx4
# Saved data for video ID AdLAkD-r9Rs
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID AegzQ_dip8k
# Saved data for video ID CHWhaAlo_ms
# Saved data for video ID HjaS82zj-Fk
# Saved data for video ID Q-QonU0QqA8
# Saved data for video ID B1YkgNDbx5o
# Saved data for video ID lowavG2SXsQ
# Saved data for video ID lALq-gHUoJA
# Saved data for video ID M_wVfpX39JE
# Saved data for video ID OmCFCS9VjZQ
# Saved data for video ID AitQQu2mFm0
# Saved data for video ID -296435dMfk
# Saved data for video ID 3OPnR9Xpltc
# Saved data for video ID SO4rB-3ZdMc
# Saved data for video ID yg_497u6JnA
# Saved data for video ID IXjs6cr5Tec
# Saved data for video ID rXRN_8Wz5kk
# Saved data for video ID xYC0sDCsI9Q
# Saved data for video ID XWGbBUENjdI
# Saved data for video ID 9SLzAsvfEbg
# Saved data for video ID PEqCa0U77mc
# Saved data for video ID I5XlgJ9IoqI
# Saved data for video ID Scxja4LMAtk
# Saved data for video ID MYP36WdBF9A
# Saved data for video ID s93Nc81Rc5c
# Saved data for video ID hheR4HgWfMA
# Saved data for video ID 2ClP539pTzA
# Saved data for video ID m66BVK2dlDk
# Saved data for video ID 8jVDEcQ0wXk
# Saved data for video ID vPZZXM_YOMM
# Saved data for video ID Kg70XKMoCz8
# Saved data for video ID AitQQu2mFm0
# Saved data for video ID 1X1M259CjXE
# Saved data for video ID et7nT2Gu1mI
# Saved data for video ID nKsaHIK6s5Q
# Saved data for video ID 962lLfW-8Jo
# Saved data for video ID a3jaFqrzpMo
# Saved data for video ID KbYW9FDm-Zk
# Saved data for video ID ttU9ADJMrds
# Saved data for video ID _niP0JaOgHY
# Saved data for video ID Se-dfXkGg_8
# Saved data for video ID H_rGN5wOkvY
# Saved data for video ID UVmxva3DAhc
# Saved data for video ID 1TUrJVjc8Bw
# Saved data for video ID Xx_PzFLh-yI
# Saved data for video ID q082eMlXI3Q
# Saved data for video ID fXYhyyJpFe8
# Saved data for video ID ttU9ADJMrds
# Saved data for video ID WiOdQQYLMU4
# Saved data for video ID GmHNYPrtwD4
# Saved data for video ID 0P8laaIxQDs
# Saved data for video ID 7cCYGq8Hz74
# Saved data for video ID x5hFEptKzdQ
# Saved data for video ID P8_KCItuZVM
# Saved data for video ID qW44hd1wlK4
# Saved data for video ID KAEOQ76BLLM
# Saved data for video ID WqRPFvZWF0k
# Saved data for video ID 5m_Z8spsyEI
# Saved data for video ID 6Nk8YoHgnss
# Saved data for video ID L9hU4xrhEDs
# Saved data for video ID m2MIpDrF7Es
# Saved data for video ID RGrtzhsXmNk
# Saved data for video ID Ld78IqdWsA8
# Saved data for video ID pDa6IMoo6dE
# Saved data for video ID mu2K847FiHU
# Saved data for video ID Ud_aN6TXuhk
# Saved data for video ID S1oIDQ6NawM
# Saved data for video ID JiTVgdbqAZA
# Saved data for video ID vNXjMTv4vHs
# Saved data for video ID Bb6EtiGJj8E
# Saved data for video ID Dp9sgIvaKPk
# Saved data for video ID DVaco_3VY38
# Saved data for video ID qZFEQcE9ToA
# Saved data for video ID 01EqB4UIhGE
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID IteIlo34srQ
# Saved data for video ID yoLlsg0e5Y8
# Saved data for video ID Ny1PTnWwSY8
# Saved data for video ID jD2InfX_96I
# Saved data for video ID vp6r1-S7Tow
# Saved data for video ID zmnh448y_ZU
# Saved data for video ID KUu18_pkvbk
# Saved data for video ID LGY-DjFsALc
# Saved data for video ID Hszu_Maneoo
# Saved data for video ID tyJNACbbAQM
# Saved data for video ID JAf_aSIJryg
# Saved data for video ID 2ofLRkYKeBk
# Saved data for video ID Ki0d6g3mwsE
# Saved data for video ID WoBWBU1bNx8
# Saved data for video ID X7V_H07J5Aw
# Saved data for video ID e7bnfHnl6PE
# Saved data for video ID Ihh_a-b_s7c
# Saved data for video ID iYO7HwQJh5o
# Saved data for video ID -7N02-aZ8Dw
# Saved data for video ID uLuZH8kkl4w
# Saved data for video ID boznb2YidbI
# Saved data for video ID t3RP9yNZNiI
# Saved data for video ID yQzk1vR7ByQ
# Saved data for video ID 6amTET0VGNg
# Saved data for video ID V239IIoGVT8
# Saved data for video ID f9-fjLyhSSc
# Saved data for video ID vwqk6fafhQw
# Saved data for video ID uexofjuWIBY
# Saved data for video ID Mv_JlKjUT4o
# Saved data for video ID 8q8sDNltMno
# Saved data for video ID gAJXnXHwO-0
# Saved data for video ID bxbfQCB1SfQ
# Saved data for video ID gidzJassbro
# Saved data for video ID BcOPKQAZcn0
# Saved data for video ID ubHPLTQIZRQ
# Saved data for video ID M0-tluVBNrY
# Saved data for video ID jnQciXRarF0
# Saved data for video ID gZB4RvZxvaI
# Saved data for video ID 0xCJzzTe0BE
# Saved data for video ID E9cugCQVDoo
# Saved data for video ID jJbM1bT8HCg
# Saved data for video ID 5-TKfOzwu9w
# Saved data for video ID 2IIfjY7Sjns
# Saved data for video ID synMe2oWQVg
# Saved data for video ID G8GAsYkZlpE
# Saved data for video ID GMa_cT2k24A
# Saved data for video ID dYjhBaQuZeg
# Saved data for video ID 3R9HL0RdfgI
# Saved data for video ID 9Yz-RCdS2Tg
# Saved data for video ID gS4oDUFrx4s
# Saved data for video ID hAGXgqaOWhg
# Saved data for video ID ItsbPEIYZgk
# Saved data for video ID 7TidO5P1CCA
# Saved data for video ID IdgC4PtMKcc
# Saved data for video ID PJ5NXXsXRWs
# Saved data for video ID Pn_A3iWUUck
# Saved data for video ID O3vRXeE-iBI
# Saved data for video ID qrBkQ8Ci2fM
# Saved data for video ID Ft_Yb3BvZKE
# Saved data for video ID THnosBVfROg
# Saved data for video ID Ds30Tjcwe1E
# Saved data for video ID 2UwqV-GMNVs
# Saved data for video ID KbVNLSd3-6c
# Saved data for video ID 6wEBiEMhbWE
# Saved data for video ID xQg6XMcbuNE
# Saved data for video ID eEY3R40s7xM
# Saved data for video ID OhqNbQi9QPk
# Saved data for video ID K7jMAcpfeMU
# Saved data for video ID 2l7YI-Vbg00
# Saved data for video ID sD0fY2WpfyY
# Saved data for video ID HP0JGjdiXmY
# Saved data for video ID CnVes9TdnPo
# Saved data for video ID FLRqdxMOKlU
# Saved data for video ID BtszJ8fm-z4
# Saved data for video ID 3Vmcd-tLZkw
# Saved data for video ID 15awMHeP1Yc
# Saved data for video ID XipB_uEexF0
# Saved data for video ID PwxxF9H3Y-k
# Saved data for video ID oChUx5m7X7Y
# Saved data for video ID Y7e7UDVoGRo
# Saved data for video ID F5PqfSiHTPQ
# Saved data for video ID p_di4Zn4wz4
# Saved data for video ID G5WyrVxE4j4
# Saved data for video ID GfMC6JohdjA
# Saved data for video ID LJe2HvfRVZg
# Saved data for video ID x-qvVKPbOgc
# Saved data for video ID pPXIfDB6OPI
# Saved data for video ID YnPIpN91xUE
# Saved data for video ID WF9W1M_GLAM
# Saved data for video ID 7OppoteeE4U
# Saved data for video ID Mo2IIMN3D_s
# Saved data for video ID fxiVBUKPoHQ
# Saved data for video ID mPBMemgN9AI
# Saved data for video ID V29xGeci8PE
# Saved data for video ID uKUzvk5_FF8
# Saved data for video ID TR6opZTqKGM
# Saved data for video ID iJUwdR_3-b4
# Saved data for video ID WQ6bqFf_jfQ
# Saved data for video ID K2o2Mc2qpjY
# Saved data for video ID 40tOHrGwoB8
# Saved data for video ID zAo6Sq-uEww
# Saved data for video ID APRGt-zJCck
# Saved data for video ID 6WUjbJEeJwM
# Saved data for video ID rfG8ce4nNh0
# Saved data for video ID 3n-77bRzwdo
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID aBuT_NpL4kM
# Saved data for video ID dKecT2jZkxI
# Saved data for video ID rnlBJNdKTGY
# Saved data for video ID IFlXeFwA_2A
# Saved data for video ID Y8YfDPlWFgk
# Saved data for video ID YGrj3cI1AJw
# Saved data for video ID zOxaUlRkFG0
# Saved data for video ID YWb1PJV7YIw
# Saved data for video ID e1nxhJQyLYI
# Saved data for video ID 925SY-xvuj8
# Saved data for video ID ZtTDs2FZ2Qw
# Saved data for video ID o8T4ZG08q8g
# Saved data for video ID IQ15BnVUgis
# Saved data for video ID FsC3do74UIo
# Saved data for video ID mTW9kWhBsmU
# Saved data for video ID tLcvEmBZEPg
# Saved data for video ID sci1pls4Lc8
# Saved data for video ID o75AqTInKDU
# Saved data for video ID JfK6bkwnlV4
# Saved data for video ID wcix-vwYJ-Q
# Saved data for video ID 6pjDaGQB86E
# Saved data for video ID 4eUJQ69uv9s
# Saved data for video ID hY8C4lcmJUk
# Saved data for video ID p5FrJ3upzTo
# Saved data for video ID ZfHU8eeK9k0
# Saved data for video ID qr670UJzrls
# Saved data for video ID 4gw7Nkr6bsg
# Saved data for video ID hcwgt6ouliU
# Saved data for video ID 6KcSrcickYA
# Saved data for video ID oJxOSkXbmA4
# Saved data for video ID NP0KDPdRmpM
# Saved data for video ID svfPBYxhYw0
# Saved data for video ID oquUbmci6Tg
# Saved data for video ID Hym9NGbDFPc
# Saved data for video ID jJ5gznUvVpU
# Saved data for video ID VKS3s-iGXyU
# Saved data for video ID sexYhhBB5ZE
# Saved data for video ID mTW9kWhBsmU
# Saved data for video ID zOxaUlRkFG0
# Saved data for video ID tLcvEmBZEPg
# Saved data for video ID FsC3do74UIo
# Saved data for video ID IQ15BnVUgis
# Saved data for video ID e1nxhJQyLYI
# Saved data for video ID IFlXeFwA_2A
# Saved data for video ID rL0ygMRBLq8
# Saved data for video ID sci1pls4Lc8
# Saved data for video ID MwVBzE7Z5gw
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID AWjvnYdGpjo
# Saved data for video ID B0xdoXk5miA
# Saved data for video ID g-Aym5nJheM
# Saved data for video ID HHAHiEgtyT8
# Saved data for video ID 2N6A4ed8s58
# Saved data for video ID FB68COIOgAo
# Saved data for video ID yY2oUKVAkdY
# Saved data for video ID t_goa94UAsU
# Saved data for video ID hXOrQ0Ao4UE
# Saved data for video ID 1w7-wlDMZrA
# Saved data for video ID M5MaGUO0JDs
# Saved data for video ID VJi8tSklSa8
# Saved data for video ID WUvTyaaNkzM
# Saved data for video ID Vj2h31kceuY
# Saved data for video ID _dmHLxqbXYU
# Saved data for video ID odBiKFAdEXc
# Saved data for video ID MO-AExWdl4Q
# Saved data for video ID sdYdnpYn-1o
# Saved data for video ID 3pXALn2ovIE
# Saved data for video ID 989TJ-9_ERI
# Saved data for video ID sWSLLO3DS1I
# Saved data for video ID HFcSGCXmsaw
# Saved data for video ID NcoRlvM1dmg
# Saved data for video ID NmfRQUZGoHI
# Saved data for video ID VXtV50HrlSU
# Saved data for video ID VkVAx09sc1k
# Saved data for video ID YiKeYcuyuoM
# Saved data for video ID uR-4D966gcE
# Saved data for video ID C3DS0tqK2TY
# Saved data for video ID VirYXQN5Lsc
# Saved data for video ID kNusX-7Nhm0
# Saved data for video ID PbO1S2M7tK4
# Saved data for video ID kSMzhhm9TlQ
# Saved data for video ID BhIeE71spKY
# Saved data for video ID Cs3U5ilCu_s
# Saved data for video ID WDZMjYJyH6k
# Saved data for video ID gvBSBtcHPmA
# Saved data for video ID 3n-77bRzwdo
# Saved data for video ID 4yJmhZBB40w
# Saved data for video ID u-SHPxxLv7w
# Saved data for video ID XlwnJiwMyZM
# Saved data for video ID 6rXByMcuAyI
# Saved data for video ID 0PWNz0k-_w4
# Saved data for video ID gJB2h-PLxYQ
# Saved data for video ID UY_KlP2nkmk
# Saved data for video ID PE7AhkSTkVE
# Saved data for video ID YVmHw72-otA
# Saved data for video ID x1vQ7Lt9s_c
# Saved data for video ID G8FGTZUPE-Q
# Saved data for video ID BFEoR68momU
# Saved data for video ID ZphxOqZ-SVk
# Saved data for video ID EebGVwZvU44
# Saved data for video ID eLPBx8YqliY
# Saved data for video ID bYvU6Hqyf-4
# Saved data for video ID jD2InfX_96I
# Saved data for video ID OFQzJyXX1zQ
# Saved data for video ID FAGRsOJY-mE
# Saved data for video ID KKg88oSUv0o
# Saved data for video ID pHBKmT6eNGw
# Saved data for video ID mJNQ7kYCwzs
# Saved data for video ID bEwr0b5xmWY
# Saved data for video ID 2I-_SV8cwsw
# Saved data for video ID CEbfT68rvUo
# Saved data for video ID 7lHHFFIAO7c
# Saved data for video ID lidOfS3jMAQ
# Saved data for video ID hit6V9HDFp4
# Saved data for video ID ababz5feAq8
# Saved data for video ID aSy8d4Pbhsw
# Saved data for video ID xmhDDkp_NW0
# Saved data for video ID M5Kvwezs1YU
# Saved data for video ID dBglfhVX6kI
# Saved data for video ID YaZNsijHebM
# Saved data for video ID 925SY-xvuj8
# Saved data for video ID eDh9VuCkMVQ
# Saved data for video ID xec6HTcn2M8
# Saved data for video ID rkNcpk9zwQA
# Saved data for video ID Gc3QvUB0PkI
# Saved data for video ID dcnfnVXHOgw
# Saved data for video ID 7sLnEs8xV_g
# Saved data for video ID CsYL-i4nCqc
# Saved data for video ID n3V5Kjxty0U
# Saved data for video ID kXfsIzTUa0M
# Saved data for video ID ibps6Xfgtso
# Saved data for video ID LzcyXHEX7SA
# Saved data for video ID rediPDPbg1E
# Saved data for video ID 2BzAGwClydc
# Saved data for video ID D9dqdbCgJQM
# Saved data for video ID itEVr97CHCU
# Saved data for video ID ZwYgDhCB2tk
# Saved data for video ID rsC3CNiCjZI
# Saved data for video ID DtlI_DetfOE
# Saved data for video ID vQerALNpNfo
# Saved data for video ID DyFML6oz0SU
# Saved data for video ID uknkM-WvsCw
# Saved data for video ID 1GwzjesYik8
# Saved data for video ID UjTTx2eYrx8
# Saved data for video ID QLHJl2_aM5Q
# Saved data for video ID 6wgntpgO-Kc
# Saved data for video ID vmt5Zb4GSes
# Saved data for video ID PPCdmEDq85Y
# Saved data for video ID vxsDXcElsQ0
# Saved data for video ID 2abpG49ekdE
# Saved data for video ID ocgjfF2AboA
# Saved data for video ID rCWOdfQ3cwQ
# Saved data for video ID _fRqTwdFJAI
# Saved data for video ID A66Yodj_DUM
# Saved data for video ID 9tMBIT-O77o
# Saved data for video ID 3_2IQ4N0jZ4
# Saved data for video ID x4Q_3_nIYhc
# Saved data for video ID 7oRy0oywNkc
# Saved data for video ID ESHiTnsKLoE
# Saved data for video ID fz8so9IYjvw
# Saved data for video ID iOdvUZoK_ps
# Saved data for video ID Y8YfDPlWFgk
# Saved data for video ID dFl9ZfQDNRo
# Saved data for video ID 4G_OXqc_Z04
# Saved data for video ID tB3wJ-bwdZc
# Saved data for video ID L8DARvr4ULw
# Saved data for video ID dgm4-3-Iv3s
# Saved data for video ID poZ2Jk8mUuU
# Saved data for video ID N81DF_xhQeE
# Saved data for video ID n5lp-jGWoz4
# Saved data for video ID HoIL0u7S1ok
# Saved data for video ID ISsvTPD6bA4
# Saved data for video ID 9CMuAiJbvv4
# Saved data for video ID 87aIgLf2v-g
# Saved data for video ID vLbpM_TP5-A
# Saved data for video ID vvX13nGB0Pg
# Saved data for video ID 2myol9hI28c
# Saved data for video ID YJnTsCNkXLw
# Saved data for video ID 8zd0z-c11mY
# Saved data for video ID 8HB8GlXTFlc
# Saved data for video ID sA9ByobJuo0
# Saved data for video ID aBuT_NpL4kM
# Saved data for video ID db7d_a0wiUg
# Saved data for video ID H-Mm6MTC-l4
# Saved data for video ID HtZyTdOW7Ps
# Saved data for video ID I-TxvHTvvcA
# Saved data for video ID y5ymHGDyLhs
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID t24yRy3gocU
# Saved data for video ID oBO0Flf3xTY
# Saved data for video ID wLnzcm4xEzw
# Saved data for video ID RxH7-LnhWnU
# Saved data for video ID AKkCJ75iktQ
# Saved data for video ID 7pevIr-uoRI
# Saved data for video ID vetES9oJRIE
# Saved data for video ID QCb5WbVAoB4
# Saved data for video ID B-m_otUiyUY
# Saved data for video ID 2q0BEYwFCC8
# Saved data for video ID 1Far3YInR1c
# Saved data for video ID RKvZAozl9Sk
# Saved data for video ID yl15dDWot5o
# Saved data for video ID ZhF468iQJpM
# Saved data for video ID 0g_4RDAxPis
# Saved data for video ID ISth4dTVbWY
# Saved data for video ID _AB8RNkkZSc
# Saved data for video ID 2_kp6QCevxc
# Saved data for video ID 2BMaVP7X-78
# Saved data for video ID zY38SV2BW7k
# Saved data for video ID 5NKVkybR_U4
# Saved data for video ID ahOp_5VVU9o
# Saved data for video ID kGZxZhgFYqw
# Saved data for video ID s-DiqLNP_90
# Saved data for video ID PzzzYm2Muk8
# Saved data for video ID i5kOLDAnIto
# Saved data for video ID b2SoSGIDCoo
# Saved data for video ID hxrL7Ig14OE
# Saved data for video ID Zlp1RsXFU9g
# Saved data for video ID dxuct08lLyY
# Saved data for video ID OPeSWafsROM
# Saved data for video ID kELU01qDx0c
# Saved data for video ID xdDX15wD8Rw
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID oDC1qahSNIY
# Saved data for video ID f_vzW8A47LQ
# Saved data for video ID H0iM9NETK1g
# Saved data for video ID YT4tW-t61Ek
# Saved data for video ID RMV7fzGc98Y
# Saved data for video ID f6zY1dD1Zi0
# Saved data for video ID oHLmdSlou88
# Saved data for video ID mTz9wFOez5w
# Saved data for video ID aMuEKHDi-qA
# Saved data for video ID pJppIep8Z5w
# Saved data for video ID 8v6WVxiFlaQ
# Saved data for video ID kHjREmsXzzk
# Saved data for video ID GJDMT38Gd2I
# Saved data for video ID Rwhe4BcBUuA
# Saved data for video ID Wu1AewUDZig
# Saved data for video ID n2y7n6jw5d0
# Saved data for video ID 3gjJDuCAEQQ
# Saved data for video ID KqokoYr_h1A
# Saved data for video ID 65yw9klPklk
# Saved data for video ID AAir4vcxRPU
# Saved data for video ID e-42776_1Ns
# Saved data for video ID 6MXMDrs6ZmA
# Saved data for video ID OiNh2DswFt4
# Saved data for video ID TPewsaLASR4
# Saved data for video ID 9RJml41PFnc
# Saved data for video ID WbebNTFCsCc
# Saved data for video ID ZGPtPkTft8g
# Saved data for video ID 7UvtU75NXTg
# Saved data for video ID ZtTDs2FZ2Qw
# Saved data for video ID spUNpyF58BY
# Saved data for video ID fNk_zzaMoSs
# Saved data for video ID 1wWiA0l2GQk
# Saved data for video ID O87pL_uS4B0
# Saved data for video ID ftnpM_RO0Jc
# Saved data for video ID OA1OJrfpP20
# Saved data for video ID g4FY_eVtEhI
# Saved data for video ID zvbdoSeGAgI
# Saved data for video ID o4JYO_K9G-s
# Saved data for video ID LF2xETZkZro
# Saved data for video ID 65yw9klPklk
# Saved data for video ID p_kFNJ5bj5c
# Saved data for video ID NqeUG8FEvCo
# Saved data for video ID vELXJPaddpI
# Saved data for video ID IVJjm5FE4x8
# Saved data for video ID WtdLamxDGa0
# Saved data for video ID OKkQWki9l_w
# Saved data for video ID 8oE1shAX96U
# Saved data for video ID CbCUXWjhtHs
# Saved data for video ID EDVJotmT584
# Saved data for video ID lNlFmnGGH60
# Saved data for video ID lqqKJA_TbRk
# Saved data for video ID MppvruSD868
# Saved data for video ID RDtITuZDZi4
# Saved data for video ID QZsX6R_amBk
# Saved data for video ID icGvJO3Zmfg
# Saved data for video ID N35Utz4xLo4
# Saved data for video ID MgcpPTtyGiw
# Saved data for video ID HC03r21qFHc
# Saved data for video ID CWQSCPi8Jq8
# Saved data for video ID XPMQ3pM-qI4
# Saved data for video ID fuxFrpaMLtw
# Saved data for video ID cK4p6nQz5DY
# Saved data for video ID hqOboV2jgVo
# Saved data for video ID qDvRK4s7yKI
# Saved data for video ID ceM6fo5GKtQ
# Saved data for video ID x-O7ck9QqTw
# Saved data for video ID 8ve6BtQ5QDI
# Saved data for video ID W0Qb6PMAOX8
# Saved data for video ID xuEcNIdq8IQ
# Saved data for video ID CERKluu27uI
# Saved data for video ID gS0hSbGI9Dg
# Saved data for video ID xzEPZEmUnFg
# Saved data for video ID ofvkZXgbIxE
# Saved data for video ID tv4v1eaVQMg
# Saved data for video ID NYpTjg1FwVs
# Saved data for video ID PG_-ax_HmS0
# Saved data for video ID KKAIzbK2zT4
# Saved data for video ID rgAH5NhsSlE
# Saved data for video ID bMQ8DRTmdkM
# Saved data for video ID p2LwHUJ9dHY
# Saved data for video ID dm1AySNBQM0
# Saved data for video ID yHzXAoFjU3k
# Saved data for video ID pSN7t79RxC4
# Saved data for video ID 11jLUuP1_uY
# Saved data for video ID AtuYU5VZAl4
# Saved data for video ID FBl6XSTaS7k
# Saved data for video ID nzPHWjEc4kg
# Saved data for video ID mA9oLEqm30s
# Saved data for video ID 33TYoybjqPg
# Saved data for video ID 3uYb-RhM7lU
# Saved data for video ID 3dA9Npkbzrc
# Saved data for video ID 6jW7FCyapXE
# Saved data for video ID EfzPazBiyOQ
# Saved data for video ID Vw_zXDW6hcw
# Saved data for video ID LV_sfMBp6gM
# Saved data for video ID f2F4pDW6Z8c
# Saved data for video ID c4IpXAY7Q4s
# Saved data for video ID EIsL1JEDmDc
# Saved data for video ID zo4Stc-raQE
# Saved data for video ID WAkLg2b5dGM
# Saved data for video ID hRcH-DK9vL0
# Saved data for video ID c6YnYr8KsSo
# Saved data for video ID CxOJ1vgvcOc
# Saved data for video ID l7kzsQwLv-0
# Saved data for video ID OC7Y6hzCOVM
# Saved data for video ID F_XmgIryugU
# Saved data for video ID KWcRYnyWDCo
# Saved data for video ID Mht9iQns1xo
# Saved data for video ID Gx6yQcmLuH8
# Saved data for video ID r2dEb74JwxE
# Saved data for video ID Lmj3s4S62fQ
# Saved data for video ID BbqbvSig6Mc
# Saved data for video ID taTcBFirCo8
# Saved data for video ID K7DboOcubmg
# Saved data for video ID JSlVUMUdTdY
# Saved data for video ID 1ovNMSQ3PVs
# Saved data for video ID 5hPD7CF0_54
# Saved data for video ID uNefokVwX2g
# Saved data for video ID SFBOsOsbGGo
# Saved data for video ID 4Mr7aEHQr8E
# Saved data for video ID yz-_EKIzz80
# Saved data for video ID pXk0PNdTZH8
# Saved data for video ID QoS_BUOLH70
# Saved data for video ID nHp5eP0ewqE
# Saved data for video ID mdj26_bUpBY
# Saved data for video ID nQGMPzPtR_Y
# Saved data for video ID qCLyiuhqatg
# Saved data for video ID BTS56I3dqEc
# Saved data for video ID uPsrGMfNOME
# Saved data for video ID xk7pYXMwUFI
# Saved data for video ID J36OKtPtTQw
# Saved data for video ID ZL2bQXRDxI4
# Saved data for video ID SlnvOW84fOU
# Saved data for video ID DqIqYXtWi50
# Saved data for video ID 4XouPJVLDRg
# Saved data for video ID PbIWuHOM0fU
# Saved data for video ID ZU1ku_QrEEA
# Saved data for video ID kKpeV7kirVY
# Saved data for video ID qSZqQRbiiug
# Saved data for video ID 73Yf5sMEU2I
# Saved data for video ID lI7fezJRPUw
# Saved data for video ID dXIkFEe4faM
# Saved data for video ID AlSjhAFlIGA
# Saved data for video ID kzQh4QwQLkc
# Saved data for video ID lPjrDmgN-aM
# Saved data for video ID q58z_xA4FWA
# Saved data for video ID cRTOT_DJ2Ms
# Saved data for video ID 4Sy3rujH5_E
# Saved data for video ID RB11M7ex2Jw
# Saved data for video ID Kb2sTe7PCC4
# Saved data for video ID EXHrpKdUL1k
# Saved data for video ID Uj2HqXYYjyQ
# Saved data for video ID rfuyoKOPJQk
# Saved data for video ID OY7GS54wkY4
# Saved data for video ID y1YDkbC3nVs
# Saved data for video ID vof6rlpeqTg
# Saved data for video ID zfhyeXbb0d4
# Saved data for video ID Qf9J3lC9ERQ
# Saved data for video ID o7FJo83S5xM
# Saved data for video ID iyJ53F27soc
# Saved data for video ID 2Iye2KsUmF0
# Saved data for video ID S7zGQWX3FZQ
# Saved data for video ID 8JeiMy1I1XY
# Saved data for video ID LW1VmZsUiLg
# Saved data for video ID LyUDZ-GYa8U
# Saved data for video ID s2IuoytNhL4
# Saved data for video ID xAlWXV0nfvI
# Saved data for video ID TJgBEI3drUc
# Saved data for video ID Y8GXpS31CGI
# Saved data for video ID 6woqcbjLXvA
# Saved data for video ID ykfnb5HKnh0
# Saved data for video ID ns2F_WPZxvQ
# Saved data for video ID hGDzjWpyIrE
# Saved data for video ID 06DQVFZtfGw
# Saved data for video ID a96c_dIHfMU
# Saved data for video ID e-42776_1Ns
# Saved data for video ID J-PLbwCYst0
# Saved data for video ID 4Jmh_FmVN6U
# Saved data for video ID tx1DFpSfKmE
# Saved data for video ID JKteP9AiW38
# Saved data for video ID YQlcHUDaNS8
# Saved data for video ID ha4bDEB32TY
# Saved data for video ID vaNrjR60uv0
# Saved data for video ID ptpkDCi3Ux4
# Saved data for video ID M9kt5ZSjX_I
# Saved data for video ID F21roAB7Zy0
# Saved data for video ID RggTx6cuXag
# Saved data for video ID 4fBE3niMdho
# Saved data for video ID 6Z2r2om2CIM
# Saved data for video ID kum70H2NcqU
# Saved data for video ID vhfjEpQWWeE
# Saved data for video ID BmUNe-nG9Pk
# Saved data for video ID gUxkDjL7Y0o
# Saved data for video ID mS130mV9XeE
# Saved data for video ID Ks9PPZx4BdY
# Saved data for video ID nlUG4OKN1IY
# Saved data for video ID DQFaiC1x7a8
# Saved data for video ID clBDc8lXnhE
# Saved data for video ID kbp9qWS-Bsk
# Saved data for video ID _Ovz4u8FL9k
# Saved data for video ID o_j0aOOO_dM
# Saved data for video ID 9HSrMDocc0c
# Saved data for video ID gMcs6RF_LrQ
# Saved data for video ID n7wi-cWxTRo
# Saved data for video ID rD0s3H1vUT4
# Saved data for video ID 0BAU2VZwzr4
# Saved data for video ID CoYNcY0Tp_4
# Saved data for video ID P7rQBnCeXtI
# Saved data for video ID X5ZhbRjS0yE
# Saved data for video ID 8ofZ6z4CMZI
# Saved data for video ID SxEZBhTzYRE
# Saved data for video ID QyphvqsW5hE
# Saved data for video ID aaurfdKG-oE
# Saved data for video ID eKKhDTc2qSc
# Saved data for video ID sbsXN7UAyiE
# Saved data for video ID 9ZVo781IhRc
# Saved data for video ID _iOoaHlRFsw
# Saved data for video ID twNfbAPfWhQ
# Saved data for video ID h7fPKoGcUZE
# Saved data for video ID RTaJeD3Auus
# Saved data for video ID RYEmqV5Nwlw
# Saved data for video ID sdUoIa46WF0
# Saved data for video ID OSQpFTEt8Iw
# Saved data for video ID qEbrbm02S68
# Saved data for video ID sbHrlppxkSM
# Saved data for video ID VqHQjtTDXiQ
# Saved data for video ID XXHOUjG4k6E
# Saved data for video ID kd2GolaOvXc
# Saved data for video ID 4snzBywrY4E
# Saved data for video ID THqzPHS8cDE
# Saved data for video ID PBuY2ervj8Y
# Saved data for video ID jfKTnTyd4ec
# Saved data for video ID 1j2jQ2PGc_s
# Saved data for video ID 8Lf8bXmJP0E
# Saved data for video ID YZ3WgPkfkiI
# Saved data for video ID 9swlkM5oWy4
# Saved data for video ID urr12jID2mI
# Saved data for video ID kjKgY0DI2fE
# Saved data for video ID iWvu4-OoqoY
# Saved data for video ID Wa_ZQyX2uh8
# Saved data for video ID KK-dGfgJYA4
# Saved data for video ID qBEOyNx1GiM
# Saved data for video ID svtUa8-C8pM
# Saved data for video ID cL0VOrcse2E
# Saved data for video ID qmMPKu9dsYU
# Saved data for video ID _o_jxgqu28c
# Saved data for video ID zAlfSE0Kvg4
# Saved data for video ID YtCiEEywalQ
# Saved data for video ID s5KOAk_iCyA
# Saved data for video ID SCsFcaCUZjA
# Saved data for video ID 3oTsZwaLjE8
# Saved data for video ID zIzufk0s_Ec
# Saved data for video ID s5ZQWciJbCk
# Saved data for video ID eBvZ5Hm7cIU
# Saved data for video ID 6X_bh-hRgpw
# Saved data for video ID 1AhdTdNTkLA
# Saved data for video ID aeS3X_EsL4c
# Saved data for video ID omrlKYCM0Xs
# Saved data for video ID f7IQqZ9zBiY
# Saved data for video ID Mt0efPzp2f0
# Saved data for video ID rUYU1hSAFDA
# Saved data for video ID bW-Z-iLHz4w
# Saved data for video ID I1svK4H6vrk
# Saved data for video ID 2JPT6W0vVxU
# Saved data for video ID 0md8u6zXn8A
# Saved data for video ID lA4eGxRcHng
# Saved data for video ID rlesPBN6Whw
# Saved data for video ID nra1yvVlZwA
# Saved data for video ID zcKCoglz9ls
# Saved data for video ID CkUECzVOxZI
# Saved data for video ID 5IXi3xMkhwU
# Saved data for video ID DW1vHMaVl7E
# Saved data for video ID KaRx67h5xzk
# Saved data for video ID pJYoGL9hMlM
# Saved data for video ID tKIToK444R0
# Saved data for video ID ISh_F_mhvoQ
# Saved data for video ID Pp6IMbFxpC0
# Saved data for video ID xqLoDNS2gxc
# Saved data for video ID a6DU7XQ69YM
# Saved data for video ID u0yvNmYuHzY
# Saved data for video ID 5GmqZJrbkXU
# Saved data for video ID lP02osStvWU
# Saved data for video ID KM1KcKKnbKk
# Saved data for video ID 4qfdCwys2ew
# Saved data for video ID yLmveB0zRPs
# Saved data for video ID tSz6O931Sj4
# Saved data for video ID kk9uN4Sfyqw
# Saved data for video ID zV03wkG2niU
# Saved data for video ID bGDUQHUIGCI
# Saved data for video ID 6D3l1_psi_8
# Saved data for video ID aS5DTRuwg78
# Saved data for video ID R1vg48m1gBg
# Saved data for video ID HJtuLoD6XCU
# Saved data for video ID NCYj1lnst5M
# Saved data for video ID WDZVUtbax2E
# Saved data for video ID 28cPmo8Mggo
# Saved data for video ID 1hk8LT3U2cU
# Saved data for video ID PEQeMIDr1tM
# Saved data for video ID JCVTLRvMCPI
# Saved data for video ID 8v9oxlcOztE
# Saved data for video ID fRJmY8UxOsA
# Saved data for video ID punrVYIOzWQ
# Saved data for video ID 97g4uToy1NI
# Saved data for video ID eAhMXGAR450
# Saved data for video ID _KwAE2ODrpU
# Saved data for video ID 9mvg2KkK67I
# Saved data for video ID x0immuqFTwM
# Saved data for video ID kWjUAULUMS4
# Saved data for video ID 2b4d-PCGOrM
# Saved data for video ID cQooL3KMwPI
# Saved data for video ID lwQk2PVrpW4
# Saved data for video ID 5AUhz9ZJPIA
# Saved data for video ID D7CFBy10Rcg
# Saved data for video ID Eed3qlHehs0
# Saved data for video ID E7u40_jiTfk
# Saved data for video ID DQgb2CubH-I
# Saved data for video ID ABPEpLO_X18
# Saved data for video ID KaaMqag7h_M
# Saved data for video ID sBZpffTA9U4
# Saved data for video ID MGMNFA6QSn0
# Saved data for video ID K4K8KzNIZQ8
# Saved data for video ID VVSkGZmud1o
# Saved data for video ID H-05EYOxL58
# Saved data for video ID 6T9P8ghbL3E
# Saved data for video ID QRLb7jTFCWk
# Saved data for video ID bTsZO1W-dVE
# Saved data for video ID 3BX-_AK0iSg
# Saved data for video ID TCJnY71giws
# Saved data for video ID QCOcpvHCwAk
# Saved data for video ID dYA0zMiFayc
# Saved data for video ID pcDWQZkUuAQ
# Saved data for video ID WbebNTFCsCc
# Saved data for video ID xH3MFkLJA08
# Saved data for video ID WsZr23eZAFc
# Saved data for video ID BTT0DjExBHw
# Saved data for video ID _7ICtZQYYFw
# Saved data for video ID -OAAfaffY-c
# Saved data for video ID ZXU6rKagW1M
# Saved data for video ID 2yegKKVB-hk
# Saved data for video ID DpIqEj4OxdQ
# Saved data for video ID 7dkfCGZPRr8
# Saved data for video ID GMjnMaA06sU
# Saved data for video ID j7iGIR79qTM
# Saved data for video ID pa-zfFavKnU
# Saved data for video ID FSfc2DjLpMo
# Saved data for video ID A3mtklyrXrA
# Saved data for video ID 8okpx23VKX0
# Saved data for video ID RgqZKphyy4k
# Saved data for video ID gzpJxPhMbQw
# Saved data for video ID XwQH2xyUO3k
# Saved data for video ID h5dVk51y0kg
# Saved data for video ID mO-gbhKP_5w
# Saved data for video ID hnN1XRjtTOU
# Saved data for video ID OC4HKs4QyMY
# Saved data for video ID 2s15gX4ia7k
# Saved data for video ID Y5Vx1LtMJqE
# Saved data for video ID MM3vi7mQ60U
# Saved data for video ID QmVj7ILvaZs
# Saved data for video ID CGQFEUlzy3c
# Saved data for video ID XmjSQdak_lY
# Saved data for video ID jqHHvS_auH0
# Saved data for video ID oxsAoG3CaHU
# Saved data for video ID pvLj1s7SOtk
# Saved data for video ID y9M6kmgSnw8
# Saved data for video ID V239IIoGVT8
# Saved data for video ID WCq3sRzsJfs
# Saved data for video ID UCs-bODZdXo
# Saved data for video ID zeqTnCIG5QQ
# Saved data for video ID NpR91wexqHA
# Saved data for video ID xwOhlrBGYiE
# ...
# Saved data for video ID 2Mf_8H9u3nw
# Saved data for video ID J3MagZ26YQA
# Saved data for video ID OK88BFOKqQA
# Saved data for video ID P-14WEZ72gQ
# Saved data for video ID Vzx9rnoIo6g
# Saved data for video ID N75l6erKB7Q
# Saved data for video ID PDvPytQc7h0
# Saved data for video ID w4zHG9g3Bwc
# Saved data for video ID Iay_RkRPMHY
# Saved data for video ID NW4xqfzO5hM
# Saved data for video ID rgp6x8NFGxQ
# Saved data for video ID TZwI4D_87ng
# Saved data for video ID U7HQ_G_N6vo
# Saved data for video ID wmV4CMDfcAY
# Saved data for video ID EwvzSFSBqQ0
# Saved data for video ID I2758fT1cYU
# Saved data for video ID -r-soRuqGuE
# Saved data for video ID iNZo_yD5PQQ
# Saved data for video ID Dfrh0OoZ86o
# Saved data for video ID ocaRNMBzcQc
# Saved data for video ID q27Ri-j5XNM
# Saved data for video ID bVoPB7fSl54
# Saved data for video ID a-a7FaA7voQ
# Saved data for video ID naHdegK57dg
# Saved data for video ID erQaVXFiLC4
# Saved data for video ID HUtkhjeO67k
# Saved data for video ID Y0Zdw4NI8EE
# Saved data for video ID ZTlLwuq3xJU
# Saved data for video ID XUjRHJkZing
# Saved data for video ID 3HMczdA7w9M
# Saved data for video ID Rms-kNWpaHE
# Saved data for video ID 5fCux99LImY
# Saved data for video ID OOU23usdmfk
# Saved data for video ID VwnHs24RZEQ
# Saved data for video ID HiOFurV3h94
# Saved data for video ID Omuzq2P5rKc
# Saved data for video ID 2i2Stfd2MpM
# Saved data for video ID 5MLRsqpDFWw
# Saved data for video ID mMCsFbAtDjk
# Saved data for video ID zbpVKbZA9is
# Saved data for video ID oNSqhQ1hCrE
# Saved data for video ID pU3n_FNib2w
# Saved data for video ID y6LlvUfINvo
# Saved data for video ID z0i-q8ARv_M
# Saved data for video ID Xn6LjHKMrqA
# Saved data for video ID XdPv_fTWd_w
# Saved data for video ID l1MTsGEY5xA
# Saved data for video ID FtKWs--F1pc
# Saved data for video ID 0R4hMmM2Whs
# Saved data for video ID HSuaXFiQ9jQ
# Saved data for video ID 4HVQghLXx48
# Saved data for video ID c7ByaI3T7Dc
# Saved data for video ID cQBoIHYIB4Y
# Saved data for video ID Yo5fcRvcbj0
# Saved data for video ID qYq2ocE32uA
# Saved data for video ID MyGEzZvg8XU
# Saved data for video ID 0hPdVih6YLg
# Saved data for video ID K16LXg5whVU
# Saved data for video ID e7BwTicZrnI
# Saved data for video ID mQ1ogvARSiw
# Saved data for video ID 3itjTS2Y9oE
# Saved data for video ID Rq10aMcToHc
# Saved data for video ID B9u2q4zUy_E
# Saved data for video ID NDCg2EkhP_4
# Saved data for video ID Eum8_hxI4Pw
# Saved data for video ID YtWqxK-3TQk
# Saved data for video ID z_yD-tc4sQg
# Saved data for video ID f20N5rPyei4
# Saved data for video ID 79Z1SQXfE-k
# Saved data for video ID AVUNRctKHDM
# Saved data for video ID vZEN4NXhmag
# Saved data for video ID e_Rs_V1mV6g
# Saved data for video ID EBUNoeQqRKM
# Saved data for video ID E4DAqYHHUG8
# Saved data for video ID JmcOJkt-xyo
# Saved data for video ID imrfuxQTPiI
# Saved data for video ID SQAZAThSats
# Saved data for video ID Lh4q9UkjOYs
# Saved data for video ID CwKGO2GvDxQ
# Saved data for video ID 1esRpUFYsX8
# Saved data for video ID 35jAcH4FLoQ
# Saved data for video ID yi2bzjw4-mA
# Saved data for video ID S1L1OYB9xWo
# Saved data for video ID ONmu5QumDME
# Saved data for video ID fswkQ1uFQa4
# Saved data for video ID VU2AXud1uYU
# Saved data for video ID trG8lBwWz24
# Saved data for video ID sKFJyqn3kaU
# Saved data for video ID DgJThzPg7zg
# Saved data for video ID 7HIpBOLeedw
# Saved data for video ID KhyvM-cl1x4
# Saved data for video ID xNte3COgKIs
# Saved data for video ID uJ0kfYNv9aU
# Saved data for video ID eto6xUOnNTw
# Saved data for video ID vSNiky9ehKo
# Saved data for video ID c05PD85j-2U
# Saved data for video ID hkVRxrNdfN8
# Saved data for video ID H2C_kP-r11g
# Saved data for video ID NhRjf3V-mMc
# Saved data for video ID _HjgOx0VS6o
# Saved data for video ID Pf6GqS5dCYQ
# Saved data for video ID hudWdUwOOq4
# Saved data for video ID Tehcvz3i38A
# Saved data for video ID GFvQfPtlVXw
# Saved data for video ID S_KfvASlR80
# Saved data for video ID atpU-flgQcw
# Saved data for video ID Ra6TiiBjulI
# Saved data for video ID 4bJmKj2yxqw
# Saved data for video ID VPXracCJflU
# Saved data for video ID GE7uWn7iwwQ
# Saved data for video ID lUG7tmhxVz4
# Saved data for video ID V8Mz4wnTAkc
# Saved data for video ID qWR_QeZiAsk
# Saved data for video ID QGT409P7L98
# Saved data for video ID YtmUf4mAnZU
# Saved data for video ID EjUTynzKOUs
# Saved data for video ID ze9b0oubKm4
# Saved data for video ID 1SUp1XxU-Nk
# Saved data for video ID JAp5A8EMlH4
# Saved data for video ID sVDDXQPdORA
# Saved data for video ID UDImqDwyDI8
# Saved data for video ID bTs7ncA_AtY
# Saved data for video ID RLf4C6WJejc
# Saved data for video ID aH97p1R5AHE
# Saved data for video ID fhRV4ArYw4I
# Saved data for video ID n2wyqq-K7_A
# Saved data for video ID C3eKwL80oZI
# Saved data for video ID m61xV0whyiI
# Saved data for video ID KK6SSYPmKEY
# Saved data for video ID IYmJ5fsFvBY
# Saved data for video ID SfRvBs_fQjM
# Saved data for video ID 0Ja9oal7Zgs
# Saved data for video ID a8mq4Gza2pQ
# Saved data for video ID 4pHV7k4nj_4
# Saved data for video ID KQOqfMEvWac
# Saved data for video ID kmsmhnlJ5UI
# Saved data for video ID rExVWct5f_M
# Saved data for video ID 4tupW4aPVxc
# Saved data for video ID mN1XUa6wq_s
# Saved data for video ID aqA99JcE1kE
# Saved data for video ID ORNI3ptnyHc
# Saved data for video ID vc44r6Oy-Ns
# Saved data for video ID nf3txdhPITM
# Saved data for video ID ueeYYDhuiyc
# Saved data for video ID uvIdzKfx1ak
# Saved data for video ID tW1qtDsfCYs
# Saved data for video ID IqkbpUtGhao
# Saved data for video ID LPYo_p013vI
# Saved data for video ID _iZAhNZTPww
# Saved data for video ID A0PwUkUR3fk
# Saved data for video ID s_TWPSvqds0
# Saved data for video ID _2qBZPG1hEo
# Saved data for video ID UIQEtY-FRho
# Saved data for video ID A3rnij1ep2I
# Saved data for video ID Q0tjy86lPPU
# Saved data for video ID 51oDtyBLaig
# Saved data for video ID YS3kt_eqOPY
# Saved data for video ID AJ0f5rsbock
# Saved data for video ID q0V22xTD6Po
# Saved data for video ID PsZBAcd_FmI
# Saved data for video ID hz2-35YR30o
# Saved data for video ID nb0iq-zJmHA
# Saved data for video ID qm4l9Zl0tNg
# Saved data for video ID j9lFc-YAztE
# Saved data for video ID uuixPaGfNz8
# Saved data for video ID khXdiuRXo54
# Saved data for video ID 3hyciaX4cSQ
# Saved data for video ID fgSVwaLCdQY
# Saved data for video ID abTbTbapWpk
# Saved data for video ID jxdu9CyfMKk
# Saved data for video ID Tkr-3s1CeUg
# Saved data for video ID MO0lgxem870
# Saved data for video ID YZXI_iBV4v4
# Saved data for video ID y4asAhMkyJE
# Saved data for video ID 7XVrrWKZRos
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID EKGkl7q9X9g
# Saved data for video ID 60Z1Shb72qA
# Saved data for video ID o0xApdj2X2A
# Saved data for video ID uOUqZBDeYnE
# Saved data for video ID pTkjWJVDk9M
# Saved data for video ID 5ThqugOd7Ps
# Saved data for video ID nkWgBBEjtHA
# Saved data for video ID 3U5n0UNXn0k
# Saved data for video ID APaSNj2mmw4
# Saved data for video ID 5uApjEBWeNE
# Saved data for video ID mZXdG5DHBYo
# Saved data for video ID NmuUgtxfYcI
# Saved data for video ID mHJOkHYmzhE
# Saved data for video ID jUSdqsy74oM
# Saved data for video ID tFpnjDidcmU
# Saved data for video ID Non5z9cR_Mw
# Saved data for video ID NyI-Z3Twu4k
# Saved data for video ID W-EVAuGHZoE
# Saved data for video ID Jh33O3LWnsc
# Saved data for video ID 64HQu8woTwg
# Saved data for video ID hbyQeAJ34h8
# Saved data for video ID CJaHqQDMxjY
# Saved data for video ID TCpqVuXOgzA
# Saved data for video ID jYwucvXBvu4
# Saved data for video ID 1iHUAEsLk2Q
# Saved data for video ID mAZi7DJ3kl4
# Saved data for video ID BzzthALIrCA
# Saved data for video ID JkXKrwaPfW0
# Saved data for video ID vrY8rH4bqw4
# Saved data for video ID In3oZPIymm8
# Saved data for video ID f20N5rPyei4
# Saved data for video ID mjoWwyPmypQ
# Saved data for video ID ULYkMrFWenA
# Saved data for video ID a5Obu-2r5-8
# Saved data for video ID 6aleOSiqT-w
# Saved data for video ID lHuRn6ACR5w
# Saved data for video ID zxrZ8EnzEPg
# Saved data for video ID Yt33zPTQ76w
# Saved data for video ID SWT4knGaDiU
# Saved data for video ID Tdg6ALREOgI
# Saved data for video ID xqvIb2rORms
# Saved data for video ID soy_jK6Dw80
# Saved data for video ID DheOD8lVHT4
# Saved data for video ID K_CWcmfVmjc
# Saved data for video ID SEnDU5B42VM
# Saved data for video ID hX2DLFGAj9w
# Saved data for video ID oIM3HAxBTmk
# Saved data for video ID K6MbaJ31zi8
# Saved data for video ID apdL-waUrQM
# Saved data for video ID fty7RCmD-2s
# Saved data for video ID dsZ4moCvCjw
# Saved data for video ID 8YpGRALRxpw
# Saved data for video ID 9gwGbNGfdgI
# Saved data for video ID RL8_1sOSlq4
# Saved data for video ID RskDcEDKlcs
# Saved data for video ID J7gGctOubks
# Saved data for video ID pQ3-YasxMfo
# Saved data for video ID ZaPSh8FREdQ
# Saved data for video ID vyii08BWROM
# Saved data for video ID VKtzY6QxVnM
# Saved data for video ID eD8XzmCSJjU
# Saved data for video ID qiDTJ6j3zuY
# Saved data for video ID H37sEMSw8Hc
# Saved data for video ID YSXRvyhodGI
# Saved data for video ID 2ss9v_bo-Qw
# Saved data for video ID ZZE9UNJslcQ
# Saved data for video ID I0MGscgQxec
# Saved data for video ID 70HmKGRoxYw
# Saved data for video ID x6AfqIW2rUM
# Saved data for video ID jU2KYuEkwnA
# Saved data for video ID ADbtdKpZm7A
# Saved data for video ID CaNvWQzfE0A
# Saved data for video ID Ad6S9WtVSuk
# Saved data for video ID UukVP7Mg3TU
# Saved data for video ID Kss13U-hvPk
# Saved data for video ID fBPxOE_PmP0
# Saved data for video ID L4d-bUcIAe4
# Saved data for video ID MO-AExWdl4Q
# Saved data for video ID WUvTyaaNkzM
# Saved data for video ID rnlBJNdKTGY
# Saved data for video ID WsQQvHm4lSw
# Saved data for video ID 0KWYXvaMpuI
# Saved data for video ID 1bH_ukYn81c
# Saved data for video ID 1kRxn2k2pOo
# Saved data for video ID kuOxDh3egN0
# Saved data for video ID YFwDVViULiA
# Saved data for video ID 5iTOphGnCtg
# Saved data for video ID eI4an8aSsgw
# Saved data for video ID u4XYcPdpYb8
# Saved data for video ID IFlXeFwA_2A
# Saved data for video ID NjvwWiCYLl4
# Saved data for video ID fiAfH47bHkc
# Saved data for video ID DZsaeDDcag0
# Saved data for video ID 7Du3Sf4ciHQ
# Saved data for video ID 2Sz7uwjsWL0
# Saved data for video ID P00OQmNxqr4
# Saved data for video ID 0uLnleSqLnU
# Saved data for video ID TnXSGdY6oaA
# Saved data for video ID z_F8a2oQtOc
# Saved data for video ID zbH5Hb9kGYk
# Saved data for video ID 2lbdQ6o8of0
# Saved data for video ID DgevvaMtQmo
# Saved data for video ID h8azDbzaABM
# Saved data for video ID CROo2ebrByM
# Saved data for video ID DIfKtQMBlCg
# Saved data for video ID kuOxDh3egN0
# Saved data for video ID L4d-bUcIAe4
# Saved data for video ID NjvwWiCYLl4
# Saved data for video ID 1bH_ukYn81c
# Saved data for video ID HfACrKJ_Y2w
# Saved data for video ID YNstP0ESndU
# Saved data for video ID 0Be_6Qaq1es
# Saved data for video ID 2n41IqOMbdc
# Saved data for video ID tt2DGYOi3hc
# Saved data for video ID q1iSmAh3n-c
# Saved data for video ID EzePYR390dw
# Saved data for video ID TzDhdvVg9_c
# Saved data for video ID pMWxnjgvUQM
# Saved data for video ID NfTO8CToMkc
# Saved data for video ID S0_qX4VJhMQ
# Saved data for video ID rfG8ce4nNh0
# Saved data for video ID tIeHLnjs5U8
# Saved data for video ID alUkVWVEP10
# Saved data for video ID z6PXviT86tI
# Saved data for video ID 2kyQ1YuzOBM
# Saved data for video ID e7QjCL7lQM4
# Saved data for video ID lAlFSHSJN0s
# Saved data for video ID 7K1sB05pE0A
# Saved data for video ID __Uw1SXPW7s
# Saved data for video ID 9_3mbfchlQE
# Saved data for video ID UcWsDwg1XwM
# Saved data for video ID yfajBIaDf1Q
# Saved data for video ID alUkVWVEP10
# Saved data for video ID EXG2Z1RpVwU
# Saved data for video ID kfF40MiS7zA
# Failed to fetch data for video ID #NAME?: {'error': {'code': 403, 'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.", 'domain': 'global', 'reason': 'forbidden'}], 'status': 'PERMISSION_DENIED'}}
# Saved data for video ID PWTdiAYQ2Cs
# Saved data for video ID YG15m2VwSjA
# Saved data for video ID AVWrB1vt5nM
# Saved data for video ID Ow6Y-g4nRls
# Saved data for video ID AKmuk0OM-DM
# Saved data for video ID rBVi_9qAKTU
# Saved data for video ID _Idra8rVS1I
# Saved data for video ID uqwC41RDPyg
# Saved data for video ID 5kwz7ajxfyA
# Saved data for video ID N2PpRnFqnqY
# Saved data for video ID A6Ad7VnSlZE
# Saved data for video ID GiCojsAWRj0
# Saved data for video ID 9vKqVkMQHKk
# Saved data for video ID lx8RcYcYVuU
# Saved data for video ID RcVA8Nj6HEo
# Saved data for video ID 54_XRjHhZzI
# Saved data for video ID I3GWzXRectE
# Saved data for video ID hN0yBctuMqU
# Saved data for video ID WjJ-kpgps1c
# Saved data for video ID 5yfh5cf4-0w
# Saved data for video ID 3d6DsjIBzJ4
# Saved data for video ID U5TKKtfBEAE
# Saved data for video ID lbVfbMJOGGY
# Saved data for video ID PxiRRXvifxM
# Saved data for video ID 7ADkMuxeENc
# Saved data for video ID uKUzvk5_FF8
# Saved data for video ID CvOQLWebWQI
# Saved data for video ID 6WUjbJEeJwM
# Saved data for video ID qBQt4wjwPdM
# Saved data for video ID 2N6A4ed8s58
# Saved data for video ID b4wRMQMvRy8
# Saved data for video ID 0YeON4p0ogw
# Saved data for video ID _D82_Wni7w4
# Saved data for video ID HGwLmX41cn4
# Saved data for video ID UVmxva3DAhc
# Saved data for video ID xt6KgxxUvFg
# Saved data for video ID WmBzmHru78w
# Saved data for video ID LkcbabVODx4
# Saved data for video ID FJwz-axH7Gk
# Saved data for video ID wPSnOqOJYM4
# Saved data for video ID 5aikdnpx-Lg
# Saved data for video ID 8stueNPVl-I
# Saved data for video ID eI4an8aSsgw
# Saved data for video ID APRGt-zJCck
# Saved data for video ID AxHvKoBj62Y
# Saved data for video ID 8uNod-pxvXg
# Saved data for video ID m2MIpDrF7Es
# Saved data for video ID NY3yWXWjYjA
# Saved data for video ID 1kRxn2k2pOo
# Saved data for video ID LGY-DjFsALc
# Saved data for video ID RE1qFUEq3hg
# Saved data for video ID 4VUWIiudCk0
# Saved data for video ID 0KWYXvaMpuI
# Saved data for video ID p_di4Zn4wz4
# Saved data for video ID hflkgUjtchg
# Saved data for video ID infTvQRD494
# Saved data for video ID aeB5BWY0RlE
# Saved data for video ID 8Qa4roJFmKM
# Saved data for video ID rjLJIVoQxz4
# Saved data for video ID aM2KyP-b4LM
# Saved data for video ID aFczzFYjUec
# Saved data for video ID NOglHJpFpbw
# Saved data for video ID 38nDV679Hao
# Saved data for video ID fYyARMqiaag
# Saved data for video ID DrDXMs-p5ik
# Saved data for video ID UiVYFFRs_BE
# Saved data for video ID dkl30KIN2Sk
# Saved data for video ID jD2InfX_96I
# Saved data for video ID o75AqTInKDU
# Saved data for video ID dNKdnDZmh4I
# Saved data for video ID rj_h8mo06Os
# Saved data for video ID 6yYiPkwUjpo
# Saved data for video ID UYiw2YdAuiI
# Saved data for video ID QVdQBMDWprg
# Saved data for video ID tsHRBcP9x6Y
# Saved data for video ID u1eaHUblFOg
# Saved data for video ID OsRodWubZY8
# Saved data for video ID Scxja4LMAtk
# Saved data for video ID bQ_B9cHBYfQ
# Saved data for video ID oixVk-jA3vM
# Saved data for video ID zEqcW4l9XEI
# Saved data for video ID 2bZ8XIkuitA
# Saved data for video ID 0WX62F7mUUI
# Saved data for video ID WqRPFvZWF0k
# Saved data for video ID 8ExJV7eVev0
# Saved data for video ID HaHsqDjWMLU
# Saved data for video ID gh8EVe2QJDU
# Saved data for video ID xlD3E635IPU
# Saved data for video ID NM0qPrIV6bw
# Saved data for video ID qMVrLhk1M28
# Saved data for video ID WT7oxiiFYt8
# Saved data for video ID r1p8pUd7AWs
# Saved data for video ID xnwoYidr40o
# Saved data for video ID _lh5DpKq3Ts
# Saved data for video ID 1EGFSefe5II
# Saved data for video ID _WFx3JDTuQg
# Saved data for video ID iNBSu_iHnn0
# Saved data for video ID ZpUrDJiJWss
# Saved data for video ID grpnc9ME4fU
# Saved data for video ID UPmW94LvVwY
# Saved data for video ID oEfZNBenV14
# Saved data for video ID DZQy2RDaSW4
# Saved data for video ID rLM4soIQwSE
# Saved data for video ID xUvm13oGqgg
# Saved data for video ID V239IIoGVT8
# Data fetching complete. Results saved to response_data.csv

# %%
import pandas as pd
df = pd.read_csv("response_data.csv", )

df.dropna()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("response_data.csv", )
#       4 df.dropna()
#
# File c:\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Python312\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Python312\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf0 in position 111493: invalid continuation byte

# %%
with open("response_data.csv", "rb") as f:
    content = f.read()

# Find the position of the problematic byte
problematic_byte_position = 111493  # Replace this with the position from the error message
print(content[problematic_byte_position - 10:problematic_byte_position + 10])  # Print surrounding bytes
# Out:
# b'nce is made for ""fa'
